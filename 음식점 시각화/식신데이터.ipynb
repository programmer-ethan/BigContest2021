# %% [markdown]
# #<식신데이터 EDA>
# KDX에서 제공받은 식신데이터를 이용해 군산에서 가장 인기있는(검색량이 높은) 맛집이 어디인지 살펴보고 그 결과를 바탕으로 folium을 이용해 지도에 표시해 한눈에 볼 수 있도록 시각화를 진행하였습니다.

# %%
# !apt -qq -y install fonts-nanum > /dev/null
 
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
 
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font = fm.FontProperties(fname=fontpath, size=10)
fm._rebuild()
 
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'
 
# Colab 의 한글 폰트 설정
plt.rc('font', family='NanumBarunGothic')
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # 군산 내에서 검색량이 많은 음식점들이 주로 위치하는 지역

# %%
jan = pd.read_csv('../data/jan.csv',encoding ='cp949')
feb = pd.read_csv('../data/feb.csv',encoding ='cp949')
mar = pd.read_csv('../data/mar.csv',encoding ='cp949')

result = pd.concat([jan,feb,mar], ignore_index=True)
result.head()
# Out:
#    LOG_DATE  INQ_CNT  ... SKSN_CGR_SCLS_NM SKSN_CGR_SCLS_CD
# 0  20210117        2  ...              한정식              101
# 1  20210101        2  ...              한정식              101
# 2  20210120        2  ...              한정식              101
# 3  20210110        2  ...              한정식              101
# 4  20210117        2  ...              한정식              101
#
# [5 rows x 11 columns]

# %% [markdown]
# 지역별로 데이터 나누기

# %%
result_gun =result[result['ADDR'].str.contains('군산')]
result_tong =result[result['ADDR'].str.contains('통영')]
result_mok =result[result['ADDR'].str.contains('목포')]

# %% [markdown]
# 군산 데이터 전처리해주기

# %%
result_gun['군산내위치'] = result_gun.ADDR.str.split(' ').str[2]
result_gun = result_gun.drop(['LOG_DATE','LOG_CITY_NM','LOG_AREA_NM','PLC_ID','SKSN_CGR_LCLS_NM','SKSN_CGR_LCLS_CD','SKSN_CGR_SCLS_CD'], axis = 1)
result_gun= result_gun.drop(['ADDR'],axis = 1)
result_gun
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        INQ_CNT      PLC_NM SKSN_CGR_SCLS_NM 군산내위치
# 0            2    힐링과메기전문점              한정식   중정길
# 1            2        황금순대              한정식   미제길
# 2            2       화산붕어찜              한정식   부곡로
# 3            2    4도C냉면&우동              한정식  동메2길
# 4            2  군산향토음식관아리랑              한정식   해망로
# ...        ...         ...              ...   ...
# 23600        2         지린성             중국음식   미원로
# 23601        2        국제반점             중국음식  구영6길
# 23602        2      전망좋은카페           카페/커피숍   옥도면
# 23603        2    4도C냉면&우동              한정식  동메2길
# 23604        2       장미칼국수    라면/칼국수/국수/수제비   큰샘길
#
# [11385 rows x 4 columns]

# %% [markdown]
# 같은 음식점끼리 검색량 합해주기

# %%
result_gun = result_gun.groupby(by =['PLC_NM','SKSN_CGR_SCLS_NM','군산내위치']).sum()
result_gun = result_gun.sort_values(by = ['INQ_CNT'],ascending=False)
result_gun
# Out:
#                                   INQ_CNT
# PLC_NM    SKSN_CGR_SCLS_NM 군산내위치
# 장미칼국수     라면/칼국수/국수/수제비    큰샘길        681
# 군산횟집      회                내항2길       484
# 복성루       중국음식             월명로        428
# 이성당       베이커리/제과점         중앙로        404
# 지린성       중국음식             미원로        365
# ...                                   ...
# 이디야 군산수송점 카페/커피숍           수송로          1
# 얼큰이칼국수    떡볶이/순대/튀김/만두     평화길          1
# 명품소머리국밥   한정식              구영5길         1
# 지곡식후경     한정식              신평3길         1
# 가시리       한정식              중앙로3가        1
#
# [2243 rows x 1 columns]

# %% [markdown]
# 군산에서 검색 50회 이상인 음식점만 추리기

# %%
famous_군산 = result_gun[result_gun['INQ_CNT']>= 50]
famous_군산 = famous_군산.sort_values(by = ['INQ_CNT'],ascending=False)
famous_군산 = famous_군산.reset_index(['군산내위치','PLC_NM',	'SKSN_CGR_SCLS_NM'])

import re
famous_군산['군산내위치'] = famous_군산['군산내위치'].map(lambda x: re.sub(r'[0-9]+', '', x))
famous_군산 = famous_군산.groupby(['군산내위치']).sum()
famous_군산 = famous_군산.sort_values(by = ['INQ_CNT'],ascending=False)

# %% [markdown]
# 50회이상 검색된 음식점들 중 가장많이 분포하는 지역 (총 검색량 300회이상) 살펴보기

# %%
famous_군산 = famous_군산[famous_군산['INQ_CNT']>= 300]

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [15, 12]

# information of groups
group_names = famous_군산.index
group_sizes = famous_군산.values
group_colors = ['yellowgreen', 'lightskyblue', 'lightcoral','silver', 'gold', 'lightgray', 'whitesmoke','lightpink']

wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}
# Pie chart

plt.pie(group_sizes, 

        labels=group_names, 
        colors=group_colors, 
        autopct='%1.2f%%', # second decimal place
        startangle=90,
        textprops={'fontsize': 13},
        wedgeprops = wedgeprops) # text font size

plt.title('군산의 맛집이 많이 분포하는 군산 내 지역',fontsize= 20)
plt.axis('equal')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.

# %% [markdown]
# # 군산에서 가장많이 검색된 음식점들

# %% [markdown]
# 150회 이상 검색된 음식점 추리기

# %%
famous_군산 = result_gun[result_gun['INQ_CNT']>= 200]
famous_군산.sort_values(by = ['INQ_CNT'],ascending=False)
famous_군산 = famous_군산.reset_index(['PLC_NM',	'SKSN_CGR_SCLS_NM','군산내위치'])
famous_군산.drop(['군산내위치'],axis = 1,inplace=True)
famous_군산
# Out:
#      PLC_NM SKSN_CGR_SCLS_NM  INQ_CNT
# 0     장미칼국수    라면/칼국수/국수/수제비      681
# 1      군산횟집                회      484
# 2       복성루             중국음식      428
# 3       이성당         베이커리/제과점      404
# 4       지린성             중국음식      365
# 5       빈해원             중국음식      350
# 6      쌍용반점             중국음식      349
# 7  새만금모싯잎송편                떡      280

# %%
famous_군산.values
# Out:
# array([['장미칼국수', '라면/칼국수/국수/수제비', 681],
#        ['군산횟집', '회', 484],
#        ['복성루', '중국음식', 428],
#        ['이성당', '베이커리/제과점', 404],
#        ['지린성', '중국음식', 365],
#        ['빈해원', '중국음식', 350],
#        ['쌍용반점', '중국음식', 349],
#        ['새만금모싯잎송편', '떡', 280]], dtype=object)

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [15, 12]

# information of groups
group_names = famous_군산['PLC_NM']
group_sizes = famous_군산['INQ_CNT']
group_colors = ['yellowgreen', 'lightskyblue', 'lightcoral','silver', 'gold', 'lightgray', 'whitesmoke','lightpink']

wedgeprops={'width': 0.5, 'edgecolor': 'w', 'linewidth': 3}
# Pie chart

plt.pie(group_sizes, 

        labels=group_names, 
        colors=group_colors, 
        autopct='%1.2f%%', # second decimal place
        startangle=90,
        textprops={'fontsize': 13},
        wedgeprops = wedgeprops) # text font size

plt.title('150회 이상 검색된 군산의 음식점',fontsize= 20)
plt.axis('equal')
plt.show()

# %% [markdown]
# # 군산에서 150회 이상 검색된 음식점 지도에 나타내보기

# %%
import folium

m = folium.Map(location = [36,126.7]) #경도 위도
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_38a02dc9013848d39d7455dfacc84c84%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_38a02dc9013848d39d7455dfacc84c84%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_38a02dc9013848d39d7455dfacc84c84%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_38a02dc9013848d39d7455dfacc84c84%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B36%2C%20126.7%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_555bd400ae36457893f23a36104d6714%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20%20%20%20%22 ...

# %%
train = pd.read_excel('경도위도_폴리움.xlsx')
train
# Out:
#         가게명         경도          위도
# 0     장미칼국수  35.985977  126.716434
# 1      군산횟집  35.994519  126.707893
# 2       복성루  35.979101  126.715608
# 3       이성당  35.987748  126.710999
# 4       지린성  35.980393  126.713976
# 5       빈해원  35.989641  126.714024
# 6      쌍용반점  35.993801  126.710283
# 7  새만금모싯잎송편  35.979882  126.751211

# %%
gunsan_location = train[['가게명', '위도', '경도']]

# %%
map = folium.Map(location = [36,126.7], zoom_start =11
                 )


for a in gunsan_location.index:
    latitude = gunsan_location.loc[a,"경도"]
    longtitude = gunsan_location.loc[a,"위도"]
    store = gunsan_location.loc[a, "가게명"]
    folium.Marker([latitude, longtitude], popup = store, tooltip =store).add_to(map)   

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_9481a3d35a894c98bad2dfb5047a7cbf%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9481a3d35a894c98bad2dfb5047a7cbf%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_9481a3d35a894c98bad2dfb5047a7cbf%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_9481a3d35a894c98bad2dfb5047a7cbf%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B36%2C%20126.7%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_df324b455e4f41c2b5a172ee4b5cadc9%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20%20%20%20%22 ...

# %% [markdown]
# 비슷한 위치에 모두 몰려있는 것을 확인할 수 있다

# %%
from folium.plugins import MarkerCluster

list1=[]
list2=[]
marker_cluster = MarkerCluster().add_to(map)
for a in gunsan_location.index:
    folium.Marker(location = [gunsan_location.loc[a,"경도"],gunsan_location.loc[a,"위도"]],
                  popup=gunsan_location.loc[a,"가게명"]).add_to(marker_cluster)
    list1.append(gunsan_location.loc[a,"경도"])
    list2.append(gunsan_location.loc[a,"위도"])
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_9481a3d35a894c98bad2dfb5047a7cbf%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9481a3d35a894c98bad2dfb5047a7cbf%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_9481a3d35a894c98bad2dfb5047a7cbf%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_9481a3d35a894c98bad2dfb5047a7cbf%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B36%2C%20126.7%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20% ...

# %% [markdown]
# 선유도와 함께 나타내보기

# %%
latitude = 35.81123841910141
longtitude = 126.41626516260177
store = "선유도"
folium.Marker([latitude, longtitude], popup = store, tooltip =store,icon = folium.Icon(color='red')).add_to(map)   

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_9481a3d35a894c98bad2dfb5047a7cbf%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9481a3d35a894c98bad2dfb5047a7cbf%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_9481a3d35a894c98bad2dfb5047a7cbf%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_9481a3d35a894c98bad2dfb5047a7cbf%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B36%2C%20126.7%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20% ...
