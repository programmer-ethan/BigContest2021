# %% [markdown]
# # 0. 네이버 블로그 크롤링 위한 준비

# %%
import re
import json
import math
import requests
import urllib.request
import urllib.error
import urllib.parse
from bs4 import BeautifulSoup
import pandas as pd

naver_client_id = "OnWRZS9VM4NjQ0wJGo2q"
naver_client_secret = "Sj9k_A_HxT"

def get_blog_count(query, display):
    encode_query = urllib.parse.quote(query)
    search_url = "https://openapi.naver.com/v1/search/blog?query=" + encode_query
    request = urllib.request.Request(search_url)

    request.add_header("X-Naver-Client-Id", naver_client_id)
    request.add_header("X-Naver-Client-Secret", naver_client_secret)

    response = urllib.request.urlopen(request)
    response_code = response.getcode()

    if response_code is 200:
        response_body = response.read()
        response_body_dict = json.loads(response_body.decode('utf-8'))

        print("Last build date: " + str(response_body_dict['lastBuildDate']))
        print("Total: " + str(response_body_dict['total']))
        print("Start: " + str(response_body_dict['start']))
        print("Display: " + str(response_body_dict['display']))

        if response_body_dict['total'] == 0:
            blog_count = 0
        else:
            blog_total = math.ceil(response_body_dict['total'] / int(display))

            if blog_total >= 1000:
                blog_count = 1000
            else:
                blog_count = blog_total

            print("Blog total: " + str(blog_total))
            print("Blog count: " + str(blog_count))

        return blog_count

def get_blog_post(query, display, start_index, sort):
    global no, df
    
    encode_query = urllib.parse.quote(query)
    search_url = "https://openapi.naver.com/v1/search/blog?query=" + encode_query + "&display=" + str(display) + "&start=" + str(start_index) + "&sort=" + sort

    request = urllib.request.Request(search_url)

    request.add_header("X-Naver-Client-Id", naver_client_id)
    request.add_header("X-Naver-Client-Secret", naver_client_secret)

    response = urllib.request.urlopen(request)
    response_code = response.getcode()

    if response_code is 200:
        response_body = response.read()
        response_body_dict = json.loads(response_body.decode('utf-8'))
        for item_index in range(0, len(response_body_dict['items'])):
            try:
                remove_html_tag = re.compile('<.*?>')
                title = re.sub(remove_html_tag, '', response_body_dict['items'][item_index]['title'])
                link = response_body_dict['items'][item_index]['link'].replace("amp;", "")
                description = re.sub(remove_html_tag, '', response_body_dict['items'][item_index]['description'])
                blogger_name = response_body_dict['items'][item_index]['bloggername']
                blogger_link = response_body_dict['items'][item_index]['bloggerlink']
                post_date = response_body_dict['items'][item_index]['postdate']

                no += 1
                post_code = requests.get(link)
                post_text = post_code.text
                post_soup = BeautifulSoup(post_text, 'lxml')

                blog_post_content_text = ""
                for mainFrame in post_soup.select('iframe#mainFrame'):
                    blog_post_url = "http://blog.naver.com" + mainFrame.get('src')
                    blog_post_code = requests.get(blog_post_url)
                    blog_post_text = blog_post_code.text
                    blog_post_soup = BeautifulSoup(blog_post_text, 'lxml')
                    
                    for blog_post_content in blog_post_soup.find_all('div', class_='se-viewer'):
                        blog_post_content_text = blog_post_content.get_text()
                        
                    for blog_post_content in blog_post_soup.find_all('div', class_='se_doc_viewer'):
                        blog_post_content_text = blog_post_content.get_text()
 
                    for blog_post_content in blog_post_soup.select('div#postViewArea'):
                        blog_post_content_text = blog_post_content.get_text()

                df.loc[no] = [title, link, description, blogger_name, blogger_link, post_date, blog_post_content_text]
                print("#", end='')
                
            except:
                item_index += 1
# Out:
# <>:25: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:63: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:25: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:63: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-1-4ae7e6133ec0>:25: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if response_code is 200:
# <ipython-input-1-4ae7e6133ec0>:63: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if response_code is 200:

# %% [markdown]
# # 1. 강릉 커피거리

# %% [markdown]
# ## (1) "강릉 커피거리"검색결과 네이버 블로그 크롤링(.csv) 후 DataFrame에 저장

# %%
no = 0                 # 몇개의 포스트를 저장하였는지 세기 위한 index
query = "강릉 커피거리"   # 검색을 원하는 문자열로서 UTF-8로 인코딩한다.
display = 10           # 검색 결과 출력 건수 지정, 10(기본값),100(최대)
start = 1              # 검색 시작 위치로 최대 1000까지 가능
sort = "sim"           # 정렬 옵션: sim(유사도순, 기본값), date(날짜순)

# 블로그를 DataFrame에 저장
df = pd.DataFrame(columns=("Title", "Link", "Description", "Blogger Name", "Blogger Link", "Post Date", "Post Contents"))

blog_count = get_blog_count(query, display)
for start_index in range(start, blog_count + 1, display):
    get_blog_post(query, display, start_index, sort)

df.to_csv("./data_강릉_커피거리.csv", header=True, index=False)
# Out:
# Last build date: Mon, 23 Aug 2021 16:17:56 +0900
# Total: 122196
# Start: 1
# Display: 10
# Blog total: 12220
# Blog count: 1000
# ########################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################

# %%
import pandas as pd
import re
import networkx as nx

df = pd.read_csv('data_강릉_커피거리.csv', encoding='utf-8')
posts = df.get('Title') + " " + df.get('Description')
post_date = df.get('Post Date')

# %% [markdown]
# ## (2) 불용어 제거, 명사 추출, 빈도수 높은 명사 추출(top_nouns)

# %%
# 불용어 제거
from eunjeon import Mecab
tagger = Mecab()

stop_words = "아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 "
stop_words = stop_words.split(' ')
stop_words[0:10]

# 명사 추출
nouns = []
for post in posts:
    for noun in tagger.nouns(post):
        if noun not in stop_words:
            nouns.append(noun)
            
nouns[0:10]

# 빈도수 높은 명사 추출 (top_nouns)
from collections import Counter
num_top_nouns = 50 ########################################################################
nouns_counter = Counter(nouns)
top_nouns = dict(nouns_counter.most_common(num_top_nouns))
top_nouns
# Out:
# {'커피': 3738,
#  '강릉': 3721,
#  '거리': 2461,
#  '안목': 1738,
#  '해변': 1453,
#  '카페': 1014,
#  '여행': 586,
#  '곳': 401,
#  '바다': 386,
#  '강원도': 194,
#  '러스': 192,
#  '빵': 188,
#  '유명': 158,
#  '강릉항': 145,
#  '맛집': 130,
#  '산토리니': 118,
#  '뷰': 116,
#  '키': 116,
#  '코스': 103,
#  '박': 95,
#  '위치': 94,
#  '보사노바': 92,
#  '한잔': 89,
#  '차': 88,
#  '추천': 88,
#  '연탄': 85,
#  '맛': 78,
#  '길': 69,
#  '주차': 69,
#  '강문': 67,
#  '층': 66,
#  '강릉시': 63,
#  '겨울': 61,
#  '날': 60,
#  '방문': 57,
#  '해수욕장': 56,
#  '커피숍': 55,
#  '동해': 53,
#  '향': 53,
#  '거': 52,
#  '시장': 52,
#  '자판기': 51,
#  '분위기': 50,
#  '경포대': 49,
#  '축제': 49,
#  '분': 49,
#  '사진': 49,
#  '도착': 49,
#  '피자': 49,
#  '정동진': 49}

# %% [markdown]
# ## (3) 블로그 내용을 문장으로 나누기
# 블로그 내용에 대해서 문장으로 나누기 위해서 문장의 끝을 나타내는 ';', '.','?', '!' 를 구분자로 사용한다.

# %%
sentences = []
for post in posts:
    sentences.extend(re.split('; |\.|\?|\!', post))
sentences[0:10]
# Out:
# ['강릉 안목해변 커피거리 경포대 강릉 커피거리 여기가 그 유명한 강릉 커피거리 안목 커피거리에는 느린 우체통도 있다',
#  ' 해마다 가을이면 강릉커피축제가 열리는데 우리가 방문했을땐 이미 축제가 끝난 후였다',
#  ' 진짜 다 커피숍 ㅋㅋㅋ 가끔',
#  '',
#  '',
#  ' ',
#  '갈만한곳 강릉 정동심곡바다부채길, 안목해변, 커피거리~ 강릉커피거리 주소: 강릉시 창해로14번길 20-1 찾아가는법 강릉IC → 강릉항 → 강릉 안목커피거리 강릉시 청해로 17에 위치한 강릉커피거리는 우리나라 최초 커피축제가 열렸던 곳으로 커피박물관과',
#  '',
#  '',
#  ' ']

# %% [markdown]
# ## (4) 문장별 명사 추출
# 블로그 내용을 문장별로 구분하였고, 구분된 문장 별로 명사를 추출하여 정리한다.

# %%
sentences_nouns = []
for sentence in sentences:
    sentence_nouns = tagger.nouns(sentence)
    sentences_nouns.append(sentence_nouns)
sentences_nouns[0:10]
# Out:
# [['강릉',
#   '안목',
#   '해변',
#   '커피',
#   '거리',
#   '경포대',
#   '강릉',
#   '커피',
#   '거리',
#   '여기',
#   '유명',
#   '강릉',
#   '커피',
#   '거리',
#   '안목',
#   '커피',
#   '거리',
#   '우체통'],
#  ['해', '가을', '강릉커피축제', '우리', '방문', '땐', '축제', '후'],
#  ['커피숍'],
#  [],
#  [],
#  [],
#  ['갈만',
#   '곳',
#   '강릉',
#   '정동',
#   '심곡',
#   '바다',
#   '부채',
#   '길',
#   '안목',
#   '해변',
#   '커피',
#   '거리',
#   '강릉',
#   '커피',
#   '거리',
#   '주소',
#   '강릉시',
#   '창해',
#   '번',
#   '길',
#   '법',
#   '강릉',
#   '강릉항',
#   '강릉',
#   '안목',
#   '커피',
#   '강릉시',
#   '청해',
#   '위치',
#   '강릉',
#   '커피',
#   '우리나라',
#   '최초',
#   '커피',
#   '축제',
#   '곳',
#   '커피',
#   '박물관'],
#  [],
#  [],
#  []]

# %% [markdown]
# ## (5) 당연하거나 여행과 관련 없는 단어들 제거

# %%
del top_nouns['커피']
del top_nouns['강릉']
del top_nouns['거리']
del top_nouns['곳']
del top_nouns['강원도']
del top_nouns['러스']
del top_nouns['유명']
del top_nouns['키']
del top_nouns['박']
del top_nouns['추천']
del top_nouns['거']
del top_nouns['분']
del top_nouns['층']
del top_nouns['날']

top_nouns
# Out:
# {'안목': 1738,
#  '해변': 1453,
#  '카페': 1014,
#  '여행': 586,
#  '바다': 386,
#  '빵': 188,
#  '강릉항': 145,
#  '맛집': 130,
#  '산토리니': 118,
#  '뷰': 116,
#  '코스': 103,
#  '위치': 94,
#  '보사노바': 92,
#  '한잔': 89,
#  '차': 88,
#  '연탄': 85,
#  '맛': 78,
#  '길': 69,
#  '주차': 69,
#  '강문': 67,
#  '강릉시': 63,
#  '겨울': 61,
#  '방문': 57,
#  '해수욕장': 56,
#  '커피숍': 55,
#  '동해': 53,
#  '향': 53,
#  '시장': 52,
#  '자판기': 51,
#  '분위기': 50,
#  '경포대': 49,
#  '축제': 49,
#  '사진': 49,
#  '도착': 49,
#  '피자': 49,
#  '정동진': 49}

# %% [markdown]
# ## (6) 상위 단어에 대해 id 적용
# - 상위 단어 top_nouns에 대해서 key에 해당하는 단어, value에 해당하는 id를 넣어 딕셔너리 형태 (word2id)로 저장한다.
# - 상위 단어 top_nouns에 대해서 key에 해당하는 id, value에 해당하는 단어를 넣어 딕셔너리 형태 (id2word)로 저장한다.

# %%
word2id = {w: i for i, w in enumerate(top_nouns.keys())}
word2id

id2word = {i: w for i, w in enumerate(top_nouns.keys())}
id2word
# Out:
# {0: '안목',
#  1: '해변',
#  2: '카페',
#  3: '여행',
#  4: '바다',
#  5: '빵',
#  6: '강릉항',
#  7: '맛집',
#  8: '산토리니',
#  9: '뷰',
#  10: '코스',
#  11: '위치',
#  12: '보사노바',
#  13: '한잔',
#  14: '차',
#  15: '연탄',
#  16: '맛',
#  17: '길',
#  18: '주차',
#  19: '강문',
#  20: '강릉시',
#  21: '겨울',
#  22: '방문',
#  23: '해수욕장',
#  24: '커피숍',
#  25: '동해',
#  26: '향',
#  27: '시장',
#  28: '자판기',
#  29: '분위기',
#  30: '경포대',
#  31: '축제',
#  32: '사진',
#  33: '도착',
#  34: '피자',
#  35: '정동진'}

# %% [markdown]
# ## (7) 인접행렬 생성
# 상위 단어들에 대해서 상위 갯수만큼의 인접행렬을 만들고, 문장 내에 상위 단어가 함께 포함된 비중에 따라 가중치를 계산하여 행렬에 표현한다. 인접 행렬을 생성하기 위해서 이전에 생성해둔 word2id를 이용한다. 행렬에서 만약 가중치가 0 이상이면 서로 연결되어 있음을 의미한다.

# %%
# weight -> 한 문장 안에서 같이 나온 단어들의 빈도수
import numpy as np
adjacent_matrix = np.zeros((len(top_nouns), len(top_nouns)), int) #zeros -> 0으로 가득 찬 array 생성
for sentence in sentences_nouns:
    for wi, i in word2id.items(): #key, value 둘 다 동시에 사용중 (wi가 key, i가 value)
        if wi in sentence:
            for wj, j in word2id.items():
                if i != j and wj in sentence:
                    adjacent_matrix[i][j] += 1
adjacent_matrix
# Out:
# array([[  0, 952, 370, ...,  20,  28,  27],
#        [952,   0, 325, ...,  17,  28,  25],
#        [370, 325,   0, ...,  10,  27,   6],
#        ...,
#        [ 20,  17,  10, ...,   0,   0,   0],
#        [ 28,  28,  27, ...,   0,   0,   0],
#        [ 27,  25,   6, ...,   0,   0,   0]])

# %%
df = pd.DataFrame(adjacent_matrix, index=word2id.keys(), columns=word2id.keys())

import seaborn as sns
cm = sns.light_palette("skyblue", as_cmap=True)
df.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_8d72f_row0_col0,#T_8d72f_row1_col1,#T_8d72f_row2_col2,#T_8d72f_row3_col3,#T_8d72f_row4_col4,#T_8d72f_row5_col5,#T_8d72f_row5_col12,#T_8d72f_row5_col21,#T_8d72f_row5_col23,#T_8d72f_row5_col25,#T_8d72f_row5_col29,#T_8d72f_row5_col30,#T_8d72f_row5_col35,#T_8d72f_row6_col6,#T_8d72f_row6_col12,#T_8d72f_row6_col15,#T_8d72f_row6_col29,#T_8d72f_row6_col34,#T_8d72f_row7_col7,#T_8d72f_row7_col13,#T_8d72f_row7_col14,#T_8d72f_row7_col28,#T_8d72f_row7_col31,#T_8d72f_row7_col32,#T_8d72f_row8_col8,#T_8d72f_row8_col9,#T_8d72f_row8_col15,#T_8d72f_row8_col17,#T_8d72f_row8_col19,#T_8d72f_row8_col26,#T_8d72f_row8_col27,#T_8d72f_row8_col28,#T_8d72f_row8_col30,#T_8d72f_row8_col32,#T_8d72f_row8_col34,#T_8d72f_row8_col35,#T_8d72f_row9_col8,#T_8d72f_row9_col9,#T_8d72f_row9_col23,#T_8d72f_row9_col24,#T_8d72f_row9_col26,#T_8d72f_row9_col27,#T_8d72f_row9_col28,#T_8d72f_row9_col31,#T_8d72f_row10_col10,#T_8d72f_row10_col14,#T_8d72f_row10_col20,#T_8d72f_row10_col23,#T_8d72f_row10_col24,#T_8d72f_row10_col28,#T_8d72f_row10_col32,#T_8d72f_row10_col33,#T_8d72f_row11_col11,#T_8d72f_row11_col21,#T_8d72f_row11_col28,#T_8d72f_row11_col29,#T_8d72f_row11_col30,#T_8d72f_row11_col35,#T_8d72f_row12_col5,#T_8d72f_row12_col6,#T_8d72f_row12_col12,#T_8d72f_row12_col15,#T_8d72f_row12_col16,#T_8d72f_row12_col17,#T_8d72f_row12_col18,#T_8d72f_row12_col19,#T_8d72f_row12_col20,#T_8d72f_row12_col23,#T_8d72f_row12_col25,#T_8d72f_row12_col27,#T_8d72f_row12_col28,#T_8d72f_row12_col30,#T_8d72f_row12_col31,#T_8d72f_row12_col33,#T_8d72f_row12_col34,#T_8d72f_row12_col35,#T_8d72f_row13_col7,#T_8d72f_row13_col13,#T_8d72f_row13_col15,#T_8d72f_row13_col16,#T_8d72f_row13_col17,#T_8d72f_row13_col19,#T_8d72f_row13_col29,#T_8d72f_row13_col34,#T_8d72f_row14_col7,#T_8d72f_row14_col10,#T_8d72f_row14_col14,#T_8d72f_row14_col20,#T_8d72f_row14_col24,#T_8d72f_row14_col26,#T_8d72f_row14_col28,#T_8d72f_row14_col29,#T_8d72f_row14_col31,#T_8d72f_row14_col34,#T_8d72f_row15_col6,#T_8d72f_row15_col8,#T_8d72f_row15_col12,#T_8d72f_row15_col13,#T_8d72f_row15_col15,#T_8d72f_row15_col19,#T_8d72f_row15_col21,#T_8d72f_row15_col23,#T_8d72f_row15_col24,#T_8d72f_row15_col25,#T_8d72f_row15_col26,#T_8d72f_row15_col27,#T_8d72f_row15_col29,#T_8d72f_row15_col30,#T_8d72f_row15_col31,#T_8d72f_row15_col35,#T_8d72f_row16_col12,#T_8d72f_row16_col13,#T_8d72f_row16_col16,#T_8d72f_row16_col18,#T_8d72f_row16_col24,#T_8d72f_row16_col25,#T_8d72f_row16_col31,#T_8d72f_row16_col33,#T_8d72f_row16_col35,#T_8d72f_row17_col8,#T_8d72f_row17_col12,#T_8d72f_row17_col13,#T_8d72f_row17_col17,#T_8d72f_row17_col21,#T_8d72f_row17_col27,#T_8d72f_row17_col29,#T_8d72f_row17_col32,#T_8d72f_row17_col33,#T_8d72f_row18_col12,#T_8d72f_row18_col16,#T_8d72f_row18_col18,#T_8d72f_row18_col21,#T_8d72f_row18_col22,#T_8d72f_row18_col23,#T_8d72f_row18_col24,#T_8d72f_row18_col25,#T_8d72f_row18_col26,#T_8d72f_row18_col28,#T_8d72f_row18_col29,#T_8d72f_row18_col31,#T_8d72f_row18_col33,#T_8d72f_row18_col34,#T_8d72f_row19_col8,#T_8d72f_row19_col12,#T_8d72f_row19_col13,#T_8d72f_row19_col15,#T_8d72f_row19_col19,#T_8d72f_row19_col23,#T_8d72f_row19_col26,#T_8d72f_row19_col28,#T_8d72f_row19_col29,#T_8d72f_row19_col31,#T_8d72f_row19_col34,#T_8d72f_row20_col10,#T_8d72f_row20_col12,#T_8d72f_row20_col14,#T_8d72f_row20_col20,#T_8d72f_row20_col21,#T_8d72f_row20_col32,#T_8d72f_row20_col33,#T_8d72f_row21_col5,#T_8d72f_row21_col11,#T_8d72f_row21_col15,#T_8d72f_row21_col17,#T_8d72f_row21_col18,#T_8d72f_row21_col20,#T_8d72f_row21_col21,#T_8d72f_row21_col23,#T_8d72f_row21_col27,#T_8d72f_row21_col28,#T_8d72f_row21_col29,#T_8d72f_row21_col30,#T_8d72f_row21_col32,#T_8d72f_row21_col34,#T_8d72f_row22_col18,#T_8d72f_row22_col22,#T_8d72f_row22_col25,#T_8d72f_row22_col27,#T_8d72f_row22_col28,#T_8d72f_row22_col30,#T_8d72f_row23_col5,#T_8d72f_row23_col9,#T_8d72f_row23_col10,#T_8d72f_row23_col12,#T_8d72f_row23_col15,#T_8d72f_row23_col18,#T_8d72f_row23_col19,#T_8d72f_row23_col21,#T_8d72f_row23_col23,#T_8d72f_row23_col26,#T_8d72f_row23_col27,#T_8d72f_row23_col31,#T_8d72f_row23_col34,#T_8d72f_row24 ...
#             background-color:  #eff1f2;
#             color:  #000000;
#         }#T_8d72f_row0_col1,#T_8d72f_row0_col2,#T_8d72f_row0_col3,#T_8d72f_row0_col4,#T_8d72f_row0_col5,#T_8d72f_row0_col6,#T_8d72f_row0_col8,#T_8d72f_row0_col11,#T_8d72f_row0_col13,#T_8d72f_row0_col17,#T_8d72f_row0_col18,

# %% [markdown]
# ## (8) 인접행렬에 대해 네트워크 생성
# 인접행렬에 대해서 네트워크를 만들고, 네트워크에 포함된 인접행렬에 대한 결과를 살펴본다.

# %%
network = nx.from_numpy_matrix(adjacent_matrix)
list(network.adjacency())
# Out:
# [(0,
#   {1: {'weight': 952},
#    2: {'weight': 370},
#    3: {'weight': 245},
#    4: {'weight': 180},
#    5: {'weight': 67},
#    6: {'weight': 79},
#    7: {'weight': 50},
#    8: {'weight': 41},
#    9: {'weight': 44},
#    10: {'weight': 50},
#    11: {'weight': 59},
#    12: {'weight': 44},
#    13: {'weight': 40},
#    14: {'weight': 30},
#    15: {'weight': 37},
#    16: {'weight': 23},
#    17: {'weight': 34},
#    18: {'weight': 26},
#    19: {'weight': 21},
#    20: {'weight': 34},
#    21: {'weight': 28},
#    22: {'weight': 20},
#    23: {'weight': 35},
#    24: {'weight': 16},
#    25: {'weight': 17},
#    26: {'weight': 18},
#    27: {'weight': 17},
#    28: {'weight': 20},
#    29: {'weight': 17},
#    30: {'weight': 12},
#    31: {'weight': 17},
#    32: {'weight': 19},
#    33: {'weight': 20},
#    34: {'weight': 28},
#    35: {'weight': 27}}),
#  (1,
#   {0: {'weight': 952},
#    2: {'weight': 325},
#    3: {'weight': 236},
#    4: {'weight': 160},
#    5: {'weight': 65},
#    6: {'weight': 57},
#    7: {'weight': 50},
#    8: {'weight': 39},
#    9: {'weight': 45},
#    10: {'weight': 43},
#    11: {'weight': 48},
#    12: {'weight': 40},
#    13: {'weight': 35},
#    14: {'weight': 32},
#    15: {'weight': 37},
#    16: {'weight': 20},
#    17: {'weight': 29},
#    18: {'weight': 22},
#    19: {'weight': 44},
#    20: {'weight': 28},
#    21: {'weight': 24},
#    22: {'weight': 20},
#    23: {'weight': 15},
#    24: {'weight': 19},
#    25: {'weight': 15},
#    26: {'weight': 16},
#    27: {'weight': 18},
#    28: {'weight': 16},
#    29: {'weight': 14},
#    30: {'weight': 18},
#    31: {'weight': 14},
#    32: {'weight': 16},
#    33: {'weight': 17},
#    34: {'weight': 28},
#    35: {'weight': 25}}),
#  (2,
#   {0: {'weight': 370},
#    1: {'weight': 325},
#    3: {'weight': 92},
#    4: {'weight': 90},
#    5: {'weight': 54},
#    6: {'weight': 17},
#    7: {'weight': 51},
#    8: {'weight': 35},
#    9: {'weight': 60},
#    10: {'weight': 18},
#    11: {'weight': 33},
#    12: {'weight': 48},
#    13: {'weight': 15},
#    14: {'weight': 11},
#    15: {'weight': 35},
#    16: {'weight': 25},
#    17: {'weight': 13},
#    18: {'weight': 11},
#    19: {'weight': 15},
#    20: {'weight': 11},
#    21: {'weight': 8},
#    22: {'weight': 21},
#    23: {'weight': 7},
#    24: {'weight': 6},
#    25: {'weight': 5},
#    26: {'weight': 6},
#    27: {'weight': 5},
#    28: {'weight': 9},
#    29: {'weight': 25},
#    30: {'weight': 12},
#    31: {'weight': 8},
#    32: {'weight': 9},
#    33: {'weight': 10},
#    34: {'weight': 27},
#    35: {'weight': 6}}),
#  (3,
#   {0: {'weight': 245},
#    1: {'weight': 236},
#    2: {'weight': 92},
#    4: {'weight': 53},
#    5: {'weight': 25},
#    6: {'weight': 21},
#    7: {'weight': 21},
#    8: {'weight': 14},
#    9: {'weight': 10},
#    10: {'weight': 53},
#    11: {'weight': 6},
#    12: {'weight': 13},
#    13: {'weight': 16},
#    14: {'weight': 16},
#    15: {'weight': 14},
#    16: {'weight': 2},
#    17: {'weight': 7},
#    18: {'weight': 5},
#    19: {'weight': 11},
#    20: {'weight': 6},
#    21: {'weight': 28},
#    22: {'weight': 9},
#    23: {'weight': 5},
#    24: {'weight': 7},
#    25: {'weight': 7},
#    26: {'weight': 2},
#    27: {'weight': 11},
#    28: {'weight': 6},
#    29: {'weight': 7},
#    30: {'weight': 10},
#    31: {'weight': 5},
#    32: {'weight': 10},
#    33: {'weight': 8},
#    34: {'weight': 7},
#    35: {'weight': 20}}),
#  (4,
#   {0: {'weight': 180},
#    1: {'weight': 160},
#    2: {'weight': 90},
#    3: {'weight': 53},
#    5: {'weight': 15},
#    6: {'weight': 16},
#    7: {'weight': 15},
#    8: {'weight': 9},
#    9: {'weight': 36},
#    10: {'weight': 7},
#    11: {'weight': 14},
#    12: {'weight': 3},
#    13: {'weight': 24},
#    14: {'weight': 6},
#    15: {'weight': 4},
#    16: {'weight': 9},
#    17: {'weight': 13},
#    18: {'weight': 5},
#    19: {'weight': 12},
#    20: {'weight': 7},
#    21: {'weight': 30},
#    22: {'weight': 3},
#    23: {'weight': 4},
#    24: {'weight': 5},
#    25: {'weight': 26},
#    26: {'weight': 18},
#    27: {'weight': 2},
#    28: {'weight': 6},
#    29: {'weight': 3},
#    30: {'weight': 11},
#    31: {'weight': 4},
#    32: {'weight': 7},
#    33: {'weight': 6},
#    34: {'weight': 6},
#    35: {'weight': 7}}),
#  (5,
#   {0: {'weight': 67},
#    1: {'weight': 65},
#    2: {'weight': 54},
#    3: {'weight': 25},
#    4: {'weight': 15},
#    6: {'weight': 3},
#    7: {'weight': 16},
#    8: {'weight': 2},
#    9: {'weight': 5},
#    10: {'weight': 2},
#    11: {'weight': 6},
#    13: {'weight': 2},
#    14: {'weight': 2},
#    15: {'weight': 61},
#    16: {'weight': 10},
#    17: {'weight': 3},
#    18: {'weight': 3},
#    19: {'weight': 4},
#    20: {'weight': 3},
#    22: {'weight': 3},
#    24: {'weight': 1},
#    26: {'weight': 3},
#    27: {'weight': 3},
#    28: {'weight': 3},
#    31: {'weight': 1},
#    32: {'weight': 2},
#    33: {'weight': 1},
#    34: {'weight': 21}}),
#  (6,
#   {0: {'weight': 79},
#    1: {'weight': 57},
#    2: {'weight': 17},
#    3: {'weight': 21},
#    4: {'weight': 16},
#    5: {'weight': 3},
#    7: {'weight': 6},
#    8: {'weight': 3},
#    9: {'weight': 3},
#    10: {'weight': 2},
#    11: {'weight': 9},
#    13: {'weight': 3},
#    14: {'weight': 5},
#    16: {'weight': 2},
#    17: {'weight': 5},
#    18: {'weight': 13},
#    19: {'weight': 1},
#    20: {'weight': 4},
#    21: {'weight': 3},
#    22: {'weight': 3},
#    23: {'weight': 3},
#    24: {'weight': 1},
#    25: {'weight': 1},
#    26: {'weight': 3},
#    27: {'weight': 1},
#    28: {'weight': 2},
#    30: {'weight': 1},
#    31: {'weight': 3},
#    32: {'weight': 3},
#    33: {'weight': 1},
#    35: {'weight': 5}}),
#  (7,
#   {0: {'weight': 50},
#    1: {'weight': 50},
#    2: {'weight': 51},
#    3: {'weight': 21},
#    4: {'weight': 15},
#    5: {'weight': 16},
#    6: {'weight': 6},
#    8: {'weight': 2},
#    9: {'weight': 13},
#    10: {'weight': 4},
#    11: {'weight': 4},
#    12: {'weight': 3},
#    15: {'weight': 12},
#    16: {'weight': 2},
#    17: {'weight': 2},
#    18: {'weight': 1},
#    19: {'weight': 7},
#    20: {'weight': 3},
#    21: {'weight': 1},
#    22: {'weight': 2},
#    23: {'weight': 1},
#    24: {'weight': 1},
#    25: {'weight': 2},
#    26: {'weight': 1},
#    27: {'weight': 1},
#    29: {'weight': 7},
#    30: {'weight': 6},
#    33: {'weight': 2},
#    34: {'weight': 17},
#    35: {'weight': 1}}),
#  (8,
#   {0: {'weight': 41},
#    1: {'weight': 39},
#    2: {'weight': 35},
#    3: {'weight': 14},
#    4: {'weight': 9},
#    5: {'weight': 2},
#    6: {'weight': 3},
#    7: {'weight': 2},
#    10: {'weight': 3},
#    11: {'weight': 2},
#    12: {'weight': 1},
#    13: {'weight': 2},
#    14: {'weight': 1},
#    16: {'weight': 3},
#    18: {'weight': 2},
#    20: {'weight': 2},
#    21: {'weight': 2},
#    22: {'weight': 2},
#    23: {'weight': 1},
#    24: {'weight': 2},
#    25: {'weight': 1},
#    29: {'weight': 4},
#    31: {'weight': 1},
#    33: {'weight': 1}}),
#  (9,
#   {0: {'weight': 44},
#    1: {'weight': 45},
#    2: {'weight': 60},
#    3: {'weight': 10},
#    4: {'weight': 36},
#    5: {'weight': 5},
#    6: {'weight': 3},
#    7: {'weight': 13},
#    10: {'weight': 1},
#    11: {'weight': 7},
#    12: {'weight': 7},
#    13: {'weight': 4},
#    14: {'weight': 1},
#    15: {'weight': 2},
#    16: {'weight': 3},
#    17: {'weight': 2},
#    18: {'weight': 1},
#    19: {'weight': 10},
#    20: {'weight': 3},
#    21: {'weight': 1},
#    22: {'weight': 4},
#    25: {'weight': 1},
#    29: {'weight': 2},
#    30: {'weight': 6},
#    32: {'weight': 1},
#    33: {'weight': 1},
#    34: {'weight': 3},
#    35: {'weight': 1}}),
#  (10,
#   {0: {'weight': 50},
#    1: {'weight': 43},
#    2: {'weight': 18},
#    3: {'weight': 53},
#    4: {'weight': 7},
#    5: {'weight': 2},
#    6: {'weight': 2},
#    7: {'weight': 4},
#    8: {'weight': 3},
#    9: {'weight': 1},
#    11: {'weight': 1},
#    12: {'weight': 1},
#    13: {'weight': 2},
#    15: {'weight': 1},
#    16: {'weight': 1},
#    17: {'weight': 5},
#    18: {'weight': 2},
#    19: {'weight': 6},
#    21: {'weight': 5},
#    22: {'weight': 4},
#    25: {'weight': 1},
#    26: {'weight': 1},
#    27: {'weight': 5},
#    29: {'weight': 1},
#    30: {'weight': 1},
#    31: {'weight': 1},
#    34: {'weight': 1},
#    35: {'weight': 3}}),
#  (11,
#   {0: {'weight': 59},
#    1: {'weight': 48},
#    2: {'weight': 33},
#    3: {'weight': 6},
#    4: {'weight': 14},
#    5: {'weight': 6},
#    6: {'weight': 9},
#    7: {'weight': 4},
#    8: {'weight': 2},
#    9: {'weight': 7},
#    10: {'weight': 1},
#    12: {'weight': 2},
#    13: {'weight': 2},
#    14: {'weight': 1},
#    15: {'weight': 2},
#    16: {'weight': 1},
#    17: {'weight': 7},
#    18: {'weight': 2},
#    19: {'weight': 2},
#    20: {'weight': 6},
#    22: {'weight': 4},
#    23: {'weight': 4},
#    24: {'weight': 3},
#    25: {'weight': 1},
#    26: {'weight': 1},
#    27: {'weight': 3},
#    31: {'weight': 1},
#    32: {'weight': 2},
#    33: {'weight': 2},
#    34: {'weight': 2}}),
#  (12,
#   {0: {'weight': 44},
#    1: {'weight': 40},
#    2: {'weight': 48},
#    3: {'weight': 13},
#    4: {'weight': 3},
#    7: {'weight': 3},
#    8: {'weight': 1},
#    9: {'weight': 7},
#    10: {'weight': 1},
#    11: {'weight': 2},
#    13: {'weight': 3},
#    14: {'weight': 1},
#    21: {'weight': 1},
#    22: {'weight': 1},
#    24: {'weight': 2},
#    26: {'weight': 1},
#    29: {'weight': 5},
#    32: {'weight': 1}}),
#  (13,
#   {0: {'weight': 40},
#    1: {'weight': 35},
#    2: {'weight': 15},
#    3: {'weight': 16},
#    4: {'weight': 24},
#    5: {'weight': 2},
#    6: {'weight': 3},
#    8: {'weight': 2},
#    9: {'weight': 4},
#    10: {'weight': 2},
#    11: {'weight': 2},
#    12: {'weight': 3},
#    14: {'weight': 9},
#    18: {'weight': 4},
#    20: {'weight': 1},
#    21: {'weight': 3},
#    22: {'weight': 1},
#    23: {'weight': 1},
#    24: {'weight': 1},
#    25: {'weight': 2},
#    26: {'weight': 2},
#    27: {'weight': 1},
#    28: {'weight': 6},
#    30: {'weight': 1},
#    31: {'weight': 1},
#    32: {'weight': 2},
#    33: {'weight': 2},
#    35: {'weight': 1}}),
#  (14,
#   {0: {'weight': 30},
#    1: {'weight': 32},
#    2: {'weight': 11},
#    3: {'weight': 16},
#    4: {'weight': 6},
#    5: {'weight': 2},
#    6: {'weight': 5},
#    8: {'weight': 1},
#    9: {'weight': 1},
#    11: {'weight': 1},
#    12: {'weight': 1},
#    13: {'weight': 9},
#    15: {'weight': 1},
#    16: {'weight': 3},
#    17: {'weight': 1},
#    18: {'weight': 6},
#    19: {'weight': 3},
#    21: {'weight': 2},
#    22: {'weight': 2},
#    23: {'weight': 3},
#    25: {'weight': 4},
#    27: {'weight': 3},
#    30: {'weight': 3},
#    32: {'weight': 1},
#    33: {'weight': 3},
#    35: {'weight': 2}}),
#  (15,
#   {0: {'weight': 37},
#    1: {'weight': 37},
#    2: {'weight': 35},
#    3: {'weight': 14},
#    4: {'weight': 4},
#    5: {'weight': 61},
#    7: {'weight': 12},
#    9: {'weight': 2},
#    10: {'weight': 1},
#    11: {'weight': 2},
#    14: {'weight': 1},
#    16: {'weight': 3},
#    17: {'weight': 3},
#    18: {'weight': 2},
#    20: {'weight': 3},
#    22: {'weight': 2},
#    28: {'weight': 1},
#    32: {'weight': 1},
#    33: {'weight': 1},
#    34: {'weight': 20}}),
#  (16,
#   {0: {'weight': 23},
#    1: {'weight': 20},
#    2: {'weight': 25},
#    3: {'weight': 2},
#    4: {'weight': 9},
#    5: {'weight': 10},
#    6: {'weight': 2},
#    7: {'weight': 2},
#    8: {'weight': 3},
#    9: {'weight': 3},
#    10: {'weight': 1},
#    11: {'weight': 1},
#    14: {'weight': 3},
#    15: {'weight': 3},
#    17: {'weight': 1},
#    19: {'weight': 3},
#    20: {'weight': 1},
#    21: {'weight': 1},
#    22: {'weight': 2},
#    23: {'weight': 1},
#    26: {'weight': 5},
#    27: {'weight': 2},
#    28: {'weight': 1},
#    29: {'weight': 5},
#    30: {'weight': 1},
#    32: {'weight': 1},
#    34: {'weight': 5}}),
#  (17,
#   {0: {'weight': 34},
#    1: {'weight': 29},
#    2: {'weight': 13},
#    3: {'weight': 7},
#    4: {'weight': 13},
#    5: {'weight': 3},
#    6: {'weight': 5},
#    7: {'weight': 2},
#    9: {'weight': 2},
#    10: {'weight': 5},
#    11: {'weight': 7},
#    14: {'weight': 1},
#    15: {'weight': 3},
#    16: {'weight': 1},
#    18: {'weight': 4},
#    19: {'weight': 1},
#    20: {'weight': 24},
#    22: {'weight': 3},
#    23: {'weight': 2},
#    24: {'weight': 1},
#    25: {'weight': 2},
#    26: {'weight': 4},
#    28: {'weight': 1},
#    30: {'weight': 1},
#    31: {'weight': 1},
#    34: {'weight': 1},
#    35: {'weight': 4}}),
#  (18,
#   {0: {'weight': 26},
#    1: {'weight': 22},
#    2: {'weight': 11},
#    3: {'weight': 5},
#    4: {'weight': 5},
#    5: {'weight': 3},
#    6: {'weight': 13},
#    7: {'weight': 1},
#    8: {'weight': 2},
#    9: {'weight': 1},
#    10: {'weight': 2},
#    11: {'weight': 2},
#    13: {'weight': 4},
#    14: {'weight': 6},
#    15: {'weight': 2},
#    17: {'weight': 4},
#    19: {'weight': 1},
#    20: {'weight': 3},
#    27: {'weight': 1},
#    30: {'weight': 1},
#    32: {'weight': 2},
#    35: {'weight': 1}}),
#  (19,
#   {0: {'weight': 21},
#    1: {'weight': 44},
#    2: {'weight': 15},
#    3: {'weight': 11},
#    4: {'weight': 12},
#    5: {'weight': 4},
#    6: {'weight': 1},
#    7: {'weight': 7},
#    9: {'weight': 10},
#    10: {'weight': 6},
#    11: {'weight': 2},
#    14: {'weight': 3},
#    16: {'weight': 3},
#    17: {'weight': 1},
#    18: {'weight': 1},
#    20: {'weight': 1},
#    21: {'weight': 1},
#    22: {'weight': 1},
#    24: {'weight': 1},
#    25: {'weight': 3},
#    27: {'weight': 2},
#    30: {'weight': 7},
#    32: {'weight': 1},
#    33: {'weight': 1},
#    35: {'weight': 2}}),
#  (20,
#   {0: {'weight': 34},
#    1: {'weight': 28},
#    2: {'weight': 11},
#    3: {'weight': 6},
#    4: {'weight': 7},
#    5: {'weight': 3},
#    6: {'weight': 4},
#    7: {'weight': 3},
#    8: {'weight': 2},
#    9: {'weight': 3},
#    11: {'weight': 6},
#    13: {'weight': 1},
#    15: {'weight': 3},
#    16: {'weight': 1},
#    17: {'weight': 24},
#    18: {'weight': 3},
#    19: {'weight': 1},
#    22: {'weight': 2},
#    23: {'weight': 3},
#    24: {'weight': 1},
#    25: {'weight': 2},
#    26: {'weight': 4},
#    27: {'weight': 1},
#    28: {'weight': 1},
#    29: {'weight': 1},
#    30: {'weight': 2},
#    31: {'weight': 4},
#    34: {'weight': 1},
#    35: {'weight': 3}}),
#  (21,
#   {0: {'weight': 28},
#    1: {'weight': 24},
#    2: {'weight': 8},
#    3: {'weight': 28},
#    4: {'weight': 30},
#    6: {'weight': 3},
#    7: {'weight': 1},
#    8: {'weight': 2},
#    9: {'weight': 1},
#    10: {'weight': 5},
#    12: {'weight': 1},
#    13: {'weight': 3},
#    14: {'weight': 2},
#    16: {'weight': 1},
#    19: {'weight': 1},
#    22: {'weight': 1},
#    24: {'weight': 1},
#    25: {'weight': 2},
#    26: {'weight': 1},
#    31: {'weight': 4},
#    33: {'weight': 1},
#    35: {'weight': 3}}),
#  (22,
#   {0: {'weight': 20},
#    1: {'weight': 20},
#    2: {'weight': 21},
#    3: {'weight': 9},
#    4: {'weight': 3},
#    5: {'weight': 3},
#    6: {'weight': 3},
#    7: {'weight': 2},
#    8: {'weight': 2},
#    9: {'weight': 4},
#    10: {'weight': 4},
#    11: {'weight': 4},
#    12: {'weight': 1},
#    13: {'weight': 1},
#    14: {'weight': 2},
#    15: {'weight': 2},
#    16: {'weight': 2},
#    17: {'weight': 3},
#    19: {'weight': 1},
#    20: {'weight': 2},
#    21: {'weight': 1},
#    23: {'weight': 1},
#    24: {'weight': 3},
#    26: {'weight': 3},
#    29: {'weight': 1},
#    31: {'weight': 1},
#    32: {'weight': 1},
#    33: {'weight': 1},
#    34: {'weight': 2},
#    35: {'weight': 1}}),
#  (23,
#   {0: {'weight': 35},
#    1: {'weight': 15},
#    2: {'weight': 7},
#    3: {'weight': 5},
#    4: {'weight': 4},
#    6: {'weight': 3},
#    7: {'weight': 1},
#    8: {'weight': 1},
#    11: {'weight': 4},
#    13: {'weight': 1},
#    14: {'weight': 3},
#    16: {'weight': 1},
#    17: {'weight': 2},
#    20: {'weight': 3},
#    22: {'weight': 1},
#    24: {'weight': 2},
#    25: {'weight': 2},
#    28: {'weight': 1},
#    29: {'weight': 1},
#    30: {'weight': 3},
#    32: {'weight': 1},
#    33: {'weight': 3},
#    35: {'weight': 5}}),
#  (24,
#   {0: {'weight': 16},
#    1: {'weight': 19},
#    2: {'weight': 6},
#    3: {'weight': 7},
#    4: {'weight': 5},
#    5: {'weight': 1},
#    6: {'weight': 1},
#    7: {'weight': 1},
#    8: {'weight': 2},
#    11: {'weight': 3},
#    12: {'weight': 2},
#    13: {'weight': 1},
#    17: {'weight': 1},
#    19: {'weight': 1},
#    20: {'weight': 1},
#    21: {'weight': 1},
#    22: {'weight': 3},
#    23: {'weight': 2},
#    25: {'weight': 1},
#    27: {'weight': 1},
#    31: {'weight': 2},
#    32: {'weight': 1},
#    35: {'weight': 1}}),
#  (25,
#   {0: {'weight': 17},
#    1: {'weight': 15},
#    2: {'weight': 5},
#    3: {'weight': 7},
#    4: {'weight': 26},
#    6: {'weight': 1},
#    7: {'weight': 2},
#    8: {'weight': 1},
#    9: {'weight': 1},
#    10: {'weight': 1},
#    11: {'weight': 1},
#    13: {'weight': 2},
#    14: {'weight': 4},
#    17: {'weight': 2},
#    19: {'weight': 3},
#    20: {'weight': 2},
#    21: {'weight': 2},
#    23: {'weight': 2},
#    24: {'weight': 1},
#    26: {'weight': 4},
#    27: {'weight': 1},
#    29: {'weight': 1},
#    35: {'weight': 2}}),
#  (26,
#   {0: {'weight': 18},
#    1: {'weight': 16},
#    2: {'weight': 6},
#    3: {'weight': 2},
#    4: {'weight': 18},
#    5: {'weight': 3},
#    6: {'weight': 3},
#    7: {'weight': 1},
#    10: {'weight': 1},
#    11: {'weight': 1},
#    12: {'weight': 1},
#    13: {'weight': 2},
#    16: {'weight': 5},
#    17: {'weight': 4},
#    20: {'weight': 4},
#    21: {'weight': 1},
#    22: {'weight': 3},
#    25: {'weight': 4},
#    27: {'weight': 1},
#    28: {'weight': 1},
#    29: {'weight': 1},
#    31: {'weight': 1}}),
#  (27,
#   {0: {'weight': 17},
#    1: {'weight': 18},
#    2: {'weight': 5},
#    3: {'weight': 11},
#    4: {'weight': 2},
#    5: {'weight': 3},
#    6: {'weight': 1},
#    7: {'weight': 1},
#    10: {'weight': 5},
#    11: {'weight': 3},
#    13: {'weight': 1},
#    14: {'weight': 3},
#    16: {'weight': 2},
#    18: {'weight': 1},
#    19: {'weight': 2},
#    20: {'weight': 1},
#    24: {'weight': 1},
#    25: {'weight': 1},
#    26: {'weight': 1},
#    28: {'weight': 1},
#    31: {'weight': 1},
#    32: {'weight': 1},
#    33: {'weight': 2},
#    35: {'weight': 3}}),
#  (28,
#   {0: {'weight': 20},
#    1: {'weight': 16},
#    2: {'weight': 9},
#    3: {'weight': 6},
#    4: {'weight': 6},
#    5: {'weight': 3},
#    6: {'weight': 2},
#    13: {'weight': 6},
#    15: {'weight': 1},
#    16: {'weight': 1},
#    17: {'weight': 1},
#    20: {'weight': 1},
#    23: {'weight': 1},
#    26: {'weight': 1},
#    27: {'weight': 1},
#    30: {'weight': 1},
#    31: {'weight': 2},
#    32: {'weight': 1},
#    33: {'weight': 1}}),
#  (29,
#   {0: {'weight': 17},
#    1: {'weight': 14},
#    2: {'weight': 25},
#    3: {'weight': 7},
#    4: {'weight': 3},
#    7: {'weight': 7},
#    8: {'weight': 4},
#    9: {'weight': 2},
#    10: {'weight': 1},
#    12: {'weight': 5},
#    16: {'weight': 5},
#    20: {'weight': 1},
#    22: {'weight': 1},
#    23: {'weight': 1},
#    25: {'weight': 1},
#    26: {'weight': 1},
#    34: {'weight': 1}}),
#  (30,
#   {0: {'weight': 12},
#    1: {'weight': 18},
#    2: {'weight': 12},
#    3: {'weight': 10},
#    4: {'weight': 11},
#    6: {'weight': 1},
#    7: {'weight': 6},
#    9: {'weight': 6},
#    10: {'weight': 1},
#    13: {'weight': 1},
#    14: {'weight': 3},
#    16: {'weight': 1},
#    17: {'weight': 1},
#    18: {'weight': 1},
#    19: {'weight': 7},
#    20: {'weight': 2},
#    23: {'weight': 3},
#    28: {'weight': 1},
#    31: {'weight': 5},
#    35: {'weight': 2}}),
#  (31,
#   {0: {'weight': 17},
#    1: {'weight': 14},
#    2: {'weight': 8},
#    3: {'weight': 5},
#    4: {'weight': 4},
#    5: {'weight': 1},
#    6: {'weight': 3},
#    8: {'weight': 1},
#    10: {'weight': 1},
#    11: {'weight': 1},
#    13: {'weight': 1},
#    17: {'weight': 1},
#    20: {'weight': 4},
#    21: {'weight': 4},
#    22: {'weight': 1},
#    24: {'weight': 2},
#    26: {'weight': 1},
#    27: {'weight': 1},
#    28: {'weight': 2},
#    30: {'weight': 5},
#    33: {'weight': 1}}),
#  (32,
#   {0: {'weight': 19},
#    1: {'weight': 16},
#    2: {'weight': 9},
#    3: {'weight': 10},
#    4: {'weight': 7},
#    5: {'weight': 2},
#    6: {'weight': 3},
#    9: {'weight': 1},
#    11: {'weight': 2},
#    12: {'weight': 1},
#    13: {'weight': 2},
#    14: {'weight': 1},
#    15: {'weight': 1},
#    16: {'weight': 1},
#    18: {'weight': 2},
#    19: {'weight': 1},
#    22: {'weight': 1},
#    23: {'weight': 1},
#    24: {'weight': 1},
#    27: {'weight': 1},
#    28: {'weight': 1},
#    33: {'weight': 1},
#    34: {'weight': 1},
#    35: {'weight': 1}}),
#  (33,
#   {0: {'weight': 20},
#    1: {'weight': 17},
#    2: {'weight': 10},
#    3: {'weight': 8},
#    4: {'weight': 6},
#    5: {'weight': 1},
#    6: {'weight': 1},
#    7: {'weight': 2},
#    8: {'weight': 1},
#    9: {'weight': 1},
#    11: {'weight': 2},
#    13: {'weight': 2},
#    14: {'weight': 3},
#    15: {'weight': 1},
#    19: {'weight': 1},
#    21: {'weight': 1},
#    22: {'weight': 1},
#    23: {'weight': 3},
#    27: {'weight': 2},
#    28: {'weight': 1},
#    31: {'weight': 1},
#    32: {'weight': 1}}),
#  (34,
#   {0: {'weight': 28},
#    1: {'weight': 28},
#    2: {'weight': 27},
#    3: {'weight': 7},
#    4: {'weight': 6},
#    5: {'weight': 21},
#    7: {'weight': 17},
#    9: {'weight': 3},
#    10: {'weight': 1},
#    11: {'weight': 2},
#    15: {'weight': 20},
#    16: {'weight': 5},
#    17: {'weight': 1},
#    20: {'weight': 1},
#    22: {'weight': 2},
#    29: {'weight': 1},
#    32: {'weight': 1}}),
#  (35,
#   {0: {'weight': 27},
#    1: {'weight': 25},
#    2: {'weight': 6},
#    3: {'weight': 20},
#    4: {'weight': 7},
#    6: {'weight': 5},
#    7: {'weight': 1},
#    9: {'weight': 1},
#    10: {'weight': 3},
#    13: {'weight': 1},
#    14: {'weight': 2},
#    17: {'weight': 4},
#    18: {'weight': 1},
#    19: {'weight': 2},
#    20: {'weight': 3},
#    21: {'weight': 3},
#    22: {'weight': 1},
#    23: {'weight': 5},
#    24: {'weight': 1},
#    25: {'weight': 2},
#    27: {'weight': 3},
#    30: {'weight': 2},
#    32: {'weight': 1}})]

# %% [markdown]
# ## (9) 시각화
# 생성된 네트워크에 대해서 데이터를 시각화하여 나타낸다. 여기서 labels 값으로 이전에 생성한 id2word를 이용한다.

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
#
import seaborn as sns

sns.set(rc = {'figure.figsize':(10,6)})
plt.rc('font', family=font_name)

def get_node_size(node_values):
    nsize=np.array([v for v in node_values])
    nsize = 1000*(nsize-min(nsize))/(max(nsize)-min(nsize))
    
    return nsize


dc = nx.degree_centrality(network).values()

# 시각화 위한
plt.figure(figsize = (20,30))
plt.axis('off') # 꺼주기

options = {
    'edge_color':'gray',
    'font_color':"black"
}

plt.subplot(322)
plt.title('Degree Centrality', fontsize=16)
nx.draw_networkx(network, font_size=16, 
                 node_color = list(dc), node_size = get_node_size(dc), 
                 labels=id2word, font_family=font_name, **options,
                 alpha=0.7, cmap=plt.cm.Blues)

plt.show()

# %% [markdown]
# # 제주도 카페거리

# %% [markdown]
# ## (1) "제주도 카페거리"검색결과 네이버 블로그 크롤링(.csv) 후 DataFrame에 저장

# %%
no = 0                 # 몇개의 포스트를 저장하였는지 세기 위한 index
query = "제주도 카페거리"   # 검색을 원하는 문자열로서 UTF-8로 인코딩한다.
display = 10           # 검색 결과 출력 건수 지정, 10(기본값),100(최대)
start = 1              # 검색 시작 위치로 최대 1000까지 가능
sort = "sim"           # 정렬 옵션: sim(유사도순, 기본값), date(날짜순)

# 블로그를 DataFrame에 저장
df = pd.DataFrame(columns=("Title", "Link", "Description", "Blogger Name", "Blogger Link", "Post Date", "Post Contents"))

blog_count = get_blog_count(query, display)
for start_index in range(start, blog_count + 1, display):
    get_blog_post(query, display, start_index, sort)

df.to_csv("./data_제주도_카페거리.csv", header=True, index=False)
# Out:
# Last build date: Mon, 23 Aug 2021 16:32:09 +0900
# Total: 288484
# Start: 1
# Display: 10
# Blog total: 28849
# Blog count: 1000
# ########################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################################

# %%
import pandas as pd
import re
import networkx as nx

df = pd.read_csv('data_제주도_카페거리.csv', encoding='utf-8')
posts = df.get('Title') + " " + df.get('Description')
post_date = df.get('Post Date')

# %% [markdown]
# ## (2) 불용어 제거, 명사 추출, 빈도수 높은 명사 추출(top_nouns)

# %%
# 불용어 제거
from eunjeon import Mecab
tagger = Mecab()

stop_words = "아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 "
stop_words = stop_words.split(' ')
stop_words[0:10]

# 명사 추출
nouns = []
for post in posts:
    for noun in tagger.nouns(post):
        if noun not in stop_words:
            nouns.append(noun)
            
nouns[0:10]

# 빈도수 높은 명사 추출 (top_nouns)
from collections import Counter
num_top_nouns = 50 ########################################################################
nouns_counter = Counter(nouns)
top_nouns = dict(nouns_counter.most_common(num_top_nouns))
top_nouns
# Out:
# {'카페': 3116,
#  '제주도': 2314,
#  '거리': 1461,
#  '애월': 1170,
#  '제주': 949,
#  '여행': 575,
#  '곳': 370,
#  '월정리': 201,
#  '이중섭': 196,
#  '바다': 192,
#  '맛집': 192,
#  '해변': 188,
#  '분': 169,
#  '두기': 165,
#  '커피': 158,
#  '단계': 155,
#  '추천': 154,
#  '차': 146,
#  '서귀포': 140,
#  '날': 139,
#  '뷰': 137,
#  '위치': 132,
#  '시': 126,
#  '사진': 113,
#  '드': 112,
#  '박': 110,
#  '도넛': 109,
#  '한담': 105,
#  '핫': 103,
#  '해수욕장': 102,
#  '봄날': 99,
#  '식당': 97,
#  '코스': 92,
#  '노티': 91,
#  '해안': 88,
#  '유명': 83,
#  '몽': 80,
#  '상드': 80,
#  '영업': 78,
#  '근처': 74,
#  '방문': 72,
#  '분위기': 71,
#  '감성': 71,
#  '길': 69,
#  '산책': 63,
#  '공항': 61,
#  '하이엔드': 59,
#  '제주시': 58,
#  '거': 56,
#  '코로나': 54}

# %% [markdown]
# ## (3) 블로그 내용을 문장으로 나누기
# 블로그 내용에 대해서 문장으로 나누기 위해서 문장의 끝을 나타내는 ';', '.','?', '!' 를 구분자로 사용한다.

# %%
sentences = []
for post in posts:
    sentences.extend(re.split('; |\.|\?|\!', post))
sentences[0:10]
# Out:
# ['로망을 실현하는 제주도 애월 카페거리 로망을 실현하는 제주도 애월 카페거리 매년 한번씩 각 지역의 이름난 카페투어를 다니곤하는데요',
#  ' 이번에 제가 다녀온 제주도 애월 카페거리 중에서도 가장 핫한 곳들만 담아 후기를 남겨보려고합니다',
#  ' 1',
#  '',
#  '',
#  '',
#  ' ',
#  '3월 제주도 여행 4박 5일 마지막 날 ( 단소 식당, 애월  카페거리) 5일째 단소 식당-&gt;애월 카페거리, 투썸플레이스-&gt;공항 제주도 마지막 날 아침입니다',
#  ' 초반엔 시간이 느리게 흐르는 것 같았으나 나름 길게 잡았던 4박 5일도 금방 지나가버렸습니다',
#  ' 이날은 날씨가 가장']

# %% [markdown]
# ## (4) 문장별 명사 추출
# 블로그 내용을 문장별로 구분하였고, 구분된 문장 별로 명사를 추출하여 정리한다.

# %%
sentences_nouns = []
for sentence in sentences:
    sentence_nouns = tagger.nouns(sentence)
    sentences_nouns.append(sentence_nouns)
sentences_nouns[0:10]
# Out:
# [['로망',
#   '실현',
#   '제주도',
#   '애월',
#   '카페',
#   '거리',
#   '로망',
#   '실현',
#   '제주도',
#   '애월',
#   '카페',
#   '거리',
#   '번',
#   '지역',
#   '카페',
#   '투어'],
#  ['이번', '제', '제주도', '애월', '카페', '거리', '중', '핫', '곳', '후기'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['월',
#   '제주도',
#   '여행',
#   '박',
#   '일',
#   '마지막',
#   '날',
#   '단소',
#   '식당',
#   '애월',
#   '카페',
#   '거리',
#   '일',
#   '단소',
#   '식당',
#   '애월',
#   '카페',
#   '거리',
#   '투썸',
#   '플레이스',
#   '공항',
#   '제주도',
#   '마지막',
#   '날',
#   '아침'],
#  ['초반', '시간', '것', '나름', '박', '일'],
#  ['이날', '날씨']]

# %% [markdown]
# ## (5) 당연하거나 여행과 관련 없는 단어들 제거

# %%
del top_nouns['제주도']
del top_nouns['커피']
del top_nouns['거리']
del top_nouns['카페']
del top_nouns['제주']
del top_nouns['곳']
del top_nouns['분']
del top_nouns['추천']
del top_nouns['근처']
del top_nouns['날']
del top_nouns['박']
del top_nouns['길']
del top_nouns['거']
del top_nouns['두기']

top_nouns
# Out:
# {'애월': 1170,
#  '여행': 575,
#  '월정리': 201,
#  '이중섭': 196,
#  '바다': 192,
#  '맛집': 192,
#  '해변': 188,
#  '단계': 155,
#  '차': 146,
#  '서귀포': 140,
#  '뷰': 137,
#  '위치': 132,
#  '시': 126,
#  '사진': 113,
#  '드': 112,
#  '도넛': 109,
#  '한담': 105,
#  '핫': 103,
#  '해수욕장': 102,
#  '봄날': 99,
#  '식당': 97,
#  '코스': 92,
#  '노티': 91,
#  '해안': 88,
#  '유명': 83,
#  '몽': 80,
#  '상드': 80,
#  '영업': 78,
#  '방문': 72,
#  '분위기': 71,
#  '감성': 71,
#  '산책': 63,
#  '공항': 61,
#  '하이엔드': 59,
#  '제주시': 58,
#  '코로나': 54}

# %% [markdown]
# ## (6) 상위 단어에 대해 id 적용
# - 상위 단어 top_nouns에 대해서 key에 해당하는 단어, value에 해당하는 id를 넣어 딕셔너리 형태 (word2id)로 저장한다.
# - 상위 단어 top_nouns에 대해서 key에 해당하는 id, value에 해당하는 단어를 넣어 딕셔너리 형태 (id2word)로 저장한다.

# %%
word2id = {w: i for i, w in enumerate(top_nouns.keys())}
word2id

id2word = {i: w for i, w in enumerate(top_nouns.keys())}
id2word
# Out:
# {0: '애월',
#  1: '여행',
#  2: '월정리',
#  3: '이중섭',
#  4: '바다',
#  5: '맛집',
#  6: '해변',
#  7: '단계',
#  8: '차',
#  9: '서귀포',
#  10: '뷰',
#  11: '위치',
#  12: '시',
#  13: '사진',
#  14: '드',
#  15: '도넛',
#  16: '한담',
#  17: '핫',
#  18: '해수욕장',
#  19: '봄날',
#  20: '식당',
#  21: '코스',
#  22: '노티',
#  23: '해안',
#  24: '유명',
#  25: '몽',
#  26: '상드',
#  27: '영업',
#  28: '방문',
#  29: '분위기',
#  30: '감성',
#  31: '산책',
#  32: '공항',
#  33: '하이엔드',
#  34: '제주시',
#  35: '코로나'}

# %% [markdown]
# ## (7) 인접행렬 생성
# 상위 단어들에 대해서 상위 갯수만큼의 인접행렬을 만들고, 문장 내에 상위 단어가 함께 포함된 비중에 따라 가중치를 계산하여 행렬에 표현한다. 인접 행렬을 생성하기 위해서 이전에 생성해둔 word2id를 이용한다. 행렬에서 만약 가중치가 0 이상이면 서로 연결되어 있음을 의미한다.

# %%
# weight -> 한 문장 안에서 같이 나온 단어들의 빈도수
import numpy as np
adjacent_matrix = np.zeros((len(top_nouns), len(top_nouns)), int) #zeros -> 0으로 가득 찬 array 생성
for sentence in sentences_nouns:
    for wi, i in word2id.items(): #key, value 둘 다 동시에 사용중 (wi가 key, i가 value)
        if wi in sentence:
            for wj, j in word2id.items():
                if i != j and wj in sentence:
                    adjacent_matrix[i][j] += 1
adjacent_matrix
# Out:
# array([[  0, 180,   1, ...,  29,  25,   5],
#        [180,   0,  30, ...,   7,   8,   4],
#        [  1,  30,   0, ...,   0,   2,   0],
#        ...,
#        [ 29,   7,   0, ...,   0,   0,   0],
#        [ 25,   8,   2, ...,   0,   0,   0],
#        [  5,   4,   0, ...,   0,   0,   0]])

# %%
df = pd.DataFrame(adjacent_matrix, index=word2id.keys(), columns=word2id.keys())

import seaborn as sns
cm = sns.light_palette("skyblue", as_cmap=True)
df.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_6201e_row0_col0,#T_6201e_row1_col1,#T_6201e_row2_col0,#T_6201e_row2_col2,#T_6201e_row2_col3,#T_6201e_row2_col7,#T_6201e_row2_col14,#T_6201e_row2_col15,#T_6201e_row2_col16,#T_6201e_row2_col19,#T_6201e_row2_col20,#T_6201e_row2_col22,#T_6201e_row2_col27,#T_6201e_row2_col33,#T_6201e_row2_col35,#T_6201e_row3_col2,#T_6201e_row3_col3,#T_6201e_row3_col6,#T_6201e_row3_col7,#T_6201e_row3_col10,#T_6201e_row3_col14,#T_6201e_row3_col15,#T_6201e_row3_col16,#T_6201e_row3_col17,#T_6201e_row3_col22,#T_6201e_row3_col23,#T_6201e_row3_col25,#T_6201e_row3_col26,#T_6201e_row3_col33,#T_6201e_row3_col35,#T_6201e_row4_col4,#T_6201e_row4_col20,#T_6201e_row4_col35,#T_6201e_row5_col5,#T_6201e_row5_col34,#T_6201e_row6_col3,#T_6201e_row6_col6,#T_6201e_row6_col7,#T_6201e_row6_col12,#T_6201e_row6_col20,#T_6201e_row6_col35,#T_6201e_row7_col0,#T_6201e_row7_col2,#T_6201e_row7_col3,#T_6201e_row7_col6,#T_6201e_row7_col7,#T_6201e_row7_col8,#T_6201e_row7_col11,#T_6201e_row7_col14,#T_6201e_row7_col15,#T_6201e_row7_col22,#T_6201e_row7_col24,#T_6201e_row7_col25,#T_6201e_row7_col26,#T_6201e_row7_col28,#T_6201e_row7_col29,#T_6201e_row7_col31,#T_6201e_row7_col32,#T_6201e_row7_col33,#T_6201e_row7_col34,#T_6201e_row8_col7,#T_6201e_row8_col8,#T_6201e_row8_col29,#T_6201e_row8_col35,#T_6201e_row9_col9,#T_6201e_row9_col14,#T_6201e_row9_col15,#T_6201e_row9_col16,#T_6201e_row9_col19,#T_6201e_row9_col22,#T_6201e_row9_col31,#T_6201e_row9_col32,#T_6201e_row9_col33,#T_6201e_row10_col3,#T_6201e_row10_col10,#T_6201e_row10_col12,#T_6201e_row10_col20,#T_6201e_row10_col35,#T_6201e_row11_col7,#T_6201e_row11_col11,#T_6201e_row11_col35,#T_6201e_row12_col6,#T_6201e_row12_col10,#T_6201e_row12_col12,#T_6201e_row12_col15,#T_6201e_row12_col16,#T_6201e_row12_col21,#T_6201e_row12_col22,#T_6201e_row12_col23,#T_6201e_row12_col24,#T_6201e_row12_col25,#T_6201e_row12_col26,#T_6201e_row12_col31,#T_6201e_row12_col33,#T_6201e_row13_col13,#T_6201e_row13_col15,#T_6201e_row13_col20,#T_6201e_row13_col27,#T_6201e_row14_col2,#T_6201e_row14_col3,#T_6201e_row14_col7,#T_6201e_row14_col9,#T_6201e_row14_col14,#T_6201e_row14_col20,#T_6201e_row14_col35,#T_6201e_row15_col2,#T_6201e_row15_col3,#T_6201e_row15_col7,#T_6201e_row15_col9,#T_6201e_row15_col12,#T_6201e_row15_col13,#T_6201e_row15_col15,#T_6201e_row15_col18,#T_6201e_row15_col20,#T_6201e_row15_col27,#T_6201e_row15_col30,#T_6201e_row15_col32,#T_6201e_row15_col34,#T_6201e_row15_col35,#T_6201e_row16_col2,#T_6201e_row16_col3,#T_6201e_row16_col9,#T_6201e_row16_col12,#T_6201e_row16_col16,#T_6201e_row16_col18,#T_6201e_row16_col20,#T_6201e_row16_col27,#T_6201e_row16_col30,#T_6201e_row17_col3,#T_6201e_row17_col17,#T_6201e_row17_col20,#T_6201e_row17_col32,#T_6201e_row18_col15,#T_6201e_row18_col16,#T_6201e_row18_col18,#T_6201e_row18_col29,#T_6201e_row18_col31,#T_6201e_row18_col33,#T_6201e_row19_col2,#T_6201e_row19_col9,#T_6201e_row19_col19,#T_6201e_row19_col29,#T_6201e_row19_col30,#T_6201e_row20_col2,#T_6201e_row20_col4,#T_6201e_row20_col6,#T_6201e_row20_col10,#T_6201e_row20_col13,#T_6201e_row20_col14,#T_6201e_row20_col15,#T_6201e_row20_col16,#T_6201e_row20_col17,#T_6201e_row20_col20,#T_6201e_row20_col21,#T_6201e_row20_col22,#T_6201e_row20_col23,#T_6201e_row20_col28,#T_6201e_row20_col29,#T_6201e_row20_col30,#T_6201e_row20_col31,#T_6201e_row20_col33,#T_6201e_row21_col12,#T_6201e_row21_col20,#T_6201e_row21_col21,#T_6201e_row21_col27,#T_6201e_row21_col35,#T_6201e_row22_col2,#T_6201e_row22_col3,#T_6201e_row22_col7,#T_6201e_row22_col9,#T_6201e_row22_col12,#T_6201e_row22_col20,#T_6201e_row22_col22,#T_6201e_row22_col35,#T_6201e_row23_col3,#T_6201e_row23_col12,#T_6201e_row23_col20,#T_6201e_row23_col23,#T_6201e_row24_col7,#T_6201e_row24_col12,#T_6201e_row24_col24,#T_6201e_row24_col27,#T_6201e_row25_col3,#T_6201e_row25_col7,#T_6201e_row25_col12,#T_6201e_row25_col25,#T_6201e_row25_col30,#T_6201e_row26_col3,#T_6201e_row26_col7,#T_6201e_row26_col12,#T_6201e_row26_col26,#T_6201e_row26_col30,#T_6201e_row27_col2,#T_6201e_row27_col13,#T_6201e_row27_col15,#T_6201e_row27_col16,#T_6201e_row ...
#             background-color:  #eff1f2;
#             color:  #000000;
#         }#T_6201e_row0_col1,#T_6201e_row0_col4,#T_6201e_row0_col5,#T_6201e_row0_col10,#T_6201e_row0_col11,#T_6201e_row0_col13,#T_6201e_row0_col15,#T_6201e_row0_col16,#T_6201e_row0_col17,#T_6201e_row0_col19,#T_6201e_row0_col23,#T_6201e_row0_col24,#T_6201e_row0_col28,#T_6201e_row0_col29,#T_6201e_row0_col30,#T_6201e_row0_col31,#T_6201e_row0_col33,#T_6201e_row0_col34,#T_6201e_row1_col0,#T_6201e_row1_col8,#T_6201e_row1_col18,#T_6201e_row1_col21,#T_6201e_row1_col32,#T_6201e_row2_col6,#T_6201e_row2_col29,#T_6201e_row3_col9,#T_6201e_row6_col2,#T_6201e_row7_col20,#T_6201e_row7_col27,#T_6201e_row7_col35,#T_6201e_row9_col3,#T_6201e_row12_col20,#T_6201e_row14_col22,#T_6201e_row20_col7,#T_6201e_row20_col12,#T_6201e_row22_col14,#T_6201e_row25_col26,#T_6201e_row26_col25{
#             background-color:  #87ceeb;
#             color:  #000000;
#         }#T_6201e_row0_col2,#T_6201e_row2_col5,#T_6201e_row2_col31,#T_6201e_row3_col31,#T_6201e_row5_col2,#T_6201e_row7_col4,#T_6201e_row7_col5,#T_6201e_row7_col17,#T_6201e_row7_col19,#T_6201e_row7_col21,#T_6201e_row7_col23,#T_6201e_row9_col0,#T_6201e_row9_col2,#T_6201e_row9_col6,#T_6201e_row9_col21,#T_6201e_row10_col14,#T_6201e_row10_col15,#T_6201e_row10_col22,#T_6201e_row11_col10,#T_6201e_row12_col2,#T_6201e_row12_col4,#T_6201e_row12_col8,#T_6201e_row13_col22,#T_6201e_row14_col10,#T_6201e_row15_col10,#T_6201e_row17_col23,#T_6201e_row17_col31,#T_6201e_row20_col5,#T_6201e_row20_col19,#T_6201e_row22_col10,#T_6201e_row23_col17,#T_6201e_row25_col2,#T_6201e_row26_col2,#T_6201e_row27_col4,#T_6201e_row27_col6,#T_6201e_row27_col10,#T_6201e_row27_col14,#T_6201e_row27_col22,#T_6201e_row28_col5,#T_6201e_row28_col14,#T_6201e_row28_col31,#T_6201e_row29_col1,#T_6201e_row29_col5,#T_6201e_row29_col14,#T_6201e_row29_col15,#T_6201e_row29_col17,#T_6201e_row29_col21,#T_6201e_row29_col22,#T_6201e_row30_col1,#T_6201e_row30_col2,#T_6201e_row30_col6,#T_6201e_row30_col8,#T_6201e_row30_col14,#T_6201e_row30_col21,#T_6201e_row30_col22,#T_6201e_row30_col23,#T_6201e_row30_col31,#T_6201e_row31_col2,#T_6201e_row31_col17,#T_6201e_row32_col10,#T_6201e_row32_col31,#T_6201e_row33_col14,#T_6201e_row33_col21,#T_6201e_row33_col22,#T_6201e_row33_col31,#T_6201e_row34_col10,#T_6201e_row34_col14,#T_6201e_row34_col21,#T_6201e_row34_col22,#T_6201e_row35_col1,#T_6201e_row35_col5{
#             background-color:  #edf0f2;

# %% [markdown]
# ## (8) 인접행렬에 대해 네트워크 생성
# 인접행렬에 대해서 네트워크를 만들고, 네트워크에 포함된 인접행렬에 대한 결과를 살펴본다.

# %%
network = nx.from_numpy_matrix(adjacent_matrix)
list(network.adjacency())
# Out:
# [(0,
#   {1: {'weight': 180},
#    2: {'weight': 1},
#    3: {'weight': 2},
#    4: {'weight': 58},
#    5: {'weight': 64},
#    6: {'weight': 48},
#    7: {'weight': 1},
#    8: {'weight': 51},
#    9: {'weight': 4},
#    10: {'weight': 45},
#    11: {'weight': 32},
#    12: {'weight': 8},
#    13: {'weight': 25},
#    14: {'weight': 57},
#    15: {'weight': 57},
#    16: {'weight': 69},
#    17: {'weight': 40},
#    18: {'weight': 26},
#    19: {'weight': 59},
#    20: {'weight': 8},
#    21: {'weight': 38},
#    22: {'weight': 54},
#    23: {'weight': 55},
#    24: {'weight': 31},
#    25: {'weight': 63},
#    26: {'weight': 63},
#    27: {'weight': 5},
#    28: {'weight': 26},
#    29: {'weight': 10},
#    30: {'weight': 15},
#    31: {'weight': 37},
#    32: {'weight': 13},
#    33: {'weight': 29},
#    34: {'weight': 25},
#    35: {'weight': 5}}),
#  (1,
#   {0: {'weight': 180},
#    2: {'weight': 30},
#    3: {'weight': 21},
#    4: {'weight': 21},
#    5: {'weight': 30},
#    6: {'weight': 32},
#    7: {'weight': 11},
#    8: {'weight': 53},
#    9: {'weight': 16},
#    10: {'weight': 18},
#    11: {'weight': 12},
#    12: {'weight': 7},
#    13: {'weight': 15},
#    14: {'weight': 21},
#    15: {'weight': 14},
#    16: {'weight': 28},
#    17: {'weight': 13},
#    18: {'weight': 27},
#    19: {'weight': 19},
#    20: {'weight': 6},
#    21: {'weight': 55},
#    22: {'weight': 19},
#    23: {'weight': 18},
#    24: {'weight': 11},
#    25: {'weight': 16},
#    26: {'weight': 16},
#    27: {'weight': 5},
#    28: {'weight': 14},
#    29: {'weight': 4},
#    30: {'weight': 4},
#    31: {'weight': 12},
#    32: {'weight': 18},
#    33: {'weight': 7},
#    34: {'weight': 8},
#    35: {'weight': 4}}),
#  (2,
#   {0: {'weight': 1},
#    1: {'weight': 30},
#    4: {'weight': 17},
#    5: {'weight': 1},
#    6: {'weight': 58},
#    8: {'weight': 6},
#    9: {'weight': 1},
#    10: {'weight': 4},
#    11: {'weight': 9},
#    12: {'weight': 1},
#    13: {'weight': 8},
#    17: {'weight': 5},
#    18: {'weight': 21},
#    21: {'weight': 3},
#    23: {'weight': 2},
#    24: {'weight': 7},
#    25: {'weight': 1},
#    26: {'weight': 1},
#    28: {'weight': 4},
#    29: {'weight': 10},
#    30: {'weight': 1},
#    31: {'weight': 1},
#    32: {'weight': 3},
#    34: {'weight': 2}}),
#  (3,
#   {0: {'weight': 2},
#    1: {'weight': 21},
#    4: {'weight': 3},
#    5: {'weight': 5},
#    8: {'weight': 6},
#    9: {'weight': 34},
#    11: {'weight': 15},
#    12: {'weight': 2},
#    13: {'weight': 2},
#    18: {'weight': 1},
#    19: {'weight': 2},
#    20: {'weight': 2},
#    21: {'weight': 4},
#    24: {'weight': 5},
#    27: {'weight': 1},
#    28: {'weight': 2},
#    29: {'weight': 1},
#    30: {'weight': 2},
#    31: {'weight': 1},
#    32: {'weight': 1},
#    34: {'weight': 2}}),
#  (4,
#   {0: {'weight': 58},
#    1: {'weight': 21},
#    2: {'weight': 17},
#    3: {'weight': 3},
#    5: {'weight': 6},
#    6: {'weight': 13},
#    7: {'weight': 1},
#    8: {'weight': 6},
#    9: {'weight': 4},
#    10: {'weight': 40},
#    11: {'weight': 11},
#    12: {'weight': 1},
#    13: {'weight': 12},
#    14: {'weight': 4},
#    15: {'weight': 2},
#    16: {'weight': 8},
#    17: {'weight': 8},
#    18: {'weight': 6},
#    19: {'weight': 6},
#    21: {'weight': 6},
#    22: {'weight': 2},
#    23: {'weight': 12},
#    24: {'weight': 4},
#    25: {'weight': 4},
#    26: {'weight': 4},
#    27: {'weight': 1},
#    28: {'weight': 4},
#    29: {'weight': 8},
#    30: {'weight': 3},
#    31: {'weight': 10},
#    32: {'weight': 2},
#    33: {'weight': 6},
#    34: {'weight': 2}}),
#  (5,
#   {0: {'weight': 64},
#    1: {'weight': 30},
#    2: {'weight': 1},
#    3: {'weight': 5},
#    4: {'weight': 6},
#    6: {'weight': 8},
#    7: {'weight': 1},
#    8: {'weight': 10},
#    9: {'weight': 4},
#    10: {'weight': 16},
#    11: {'weight': 6},
#    12: {'weight': 5},
#    13: {'weight': 8},
#    14: {'weight': 9},
#    15: {'weight': 10},
#    16: {'weight': 7},
#    17: {'weight': 12},
#    18: {'weight': 8},
#    19: {'weight': 5},
#    20: {'weight': 1},
#    21: {'weight': 7},
#    22: {'weight': 8},
#    23: {'weight': 3},
#    24: {'weight': 6},
#    25: {'weight': 6},
#    26: {'weight': 6},
#    27: {'weight': 5},
#    28: {'weight': 1},
#    29: {'weight': 1},
#    30: {'weight': 4},
#    31: {'weight': 3},
#    32: {'weight': 2},
#    33: {'weight': 3},
#    35: {'weight': 1}}),
#  (6,
#   {0: {'weight': 48},
#    1: {'weight': 32},
#    2: {'weight': 58},
#    4: {'weight': 13},
#    5: {'weight': 8},
#    8: {'weight': 10},
#    9: {'weight': 1},
#    10: {'weight': 6},
#    11: {'weight': 10},
#    13: {'weight': 8},
#    14: {'weight': 6},
#    15: {'weight': 7},
#    16: {'weight': 35},
#    17: {'weight': 6},
#    18: {'weight': 10},
#    19: {'weight': 10},
#    21: {'weight': 8},
#    22: {'weight': 5},
#    23: {'weight': 6},
#    24: {'weight': 9},
#    25: {'weight': 5},
#    26: {'weight': 5},
#    27: {'weight': 1},
#    28: {'weight': 6},
#    29: {'weight': 5},
#    30: {'weight': 1},
#    31: {'weight': 6},
#    32: {'weight': 4},
#    33: {'weight': 2},
#    34: {'weight': 4}}),
#  (7,
#   {0: {'weight': 1},
#    1: {'weight': 11},
#    4: {'weight': 1},
#    5: {'weight': 1},
#    9: {'weight': 2},
#    10: {'weight': 2},
#    12: {'weight': 28},
#    13: {'weight': 1},
#    16: {'weight': 1},
#    17: {'weight': 1},
#    18: {'weight': 9},
#    19: {'weight': 1},
#    20: {'weight': 35},
#    21: {'weight': 1},
#    23: {'weight': 1},
#    27: {'weight': 28},
#    30: {'weight': 1},
#    35: {'weight': 25}}),
#  (8,
#   {0: {'weight': 51},
#    1: {'weight': 53},
#    2: {'weight': 6},
#    3: {'weight': 6},
#    4: {'weight': 6},
#    5: {'weight': 10},
#    6: {'weight': 10},
#    9: {'weight': 7},
#    10: {'weight': 6},
#    11: {'weight': 8},
#    12: {'weight': 1},
#    13: {'weight': 2},
#    14: {'weight': 6},
#    15: {'weight': 2},
#    16: {'weight': 3},
#    17: {'weight': 2},
#    18: {'weight': 11},
#    19: {'weight': 3},
#    20: {'weight': 3},
#    21: {'weight': 12},
#    22: {'weight': 3},
#    23: {'weight': 4},
#    24: {'weight': 4},
#    25: {'weight': 2},
#    26: {'weight': 2},
#    27: {'weight': 2},
#    28: {'weight': 6},
#    30: {'weight': 1},
#    31: {'weight': 2},
#    32: {'weight': 9},
#    33: {'weight': 2},
#    34: {'weight': 2}}),
#  (9,
#   {0: {'weight': 4},
#    1: {'weight': 16},
#    2: {'weight': 1},
#    3: {'weight': 34},
#    4: {'weight': 4},
#    5: {'weight': 4},
#    6: {'weight': 1},
#    7: {'weight': 2},
#    8: {'weight': 7},
#    10: {'weight': 7},
#    11: {'weight': 7},
#    12: {'weight': 3},
#    13: {'weight': 7},
#    17: {'weight': 5},
#    18: {'weight': 1},
#    20: {'weight': 2},
#    21: {'weight': 1},
#    23: {'weight': 2},
#    24: {'weight': 2},
#    25: {'weight': 1},
#    26: {'weight': 1},
#    27: {'weight': 2},
#    28: {'weight': 1},
#    29: {'weight': 4},
#    30: {'weight': 6},
#    34: {'weight': 1},
#    35: {'weight': 2}}),
#  (10,
#   {0: {'weight': 45},
#    1: {'weight': 18},
#    2: {'weight': 4},
#    4: {'weight': 40},
#    5: {'weight': 16},
#    6: {'weight': 6},
#    7: {'weight': 2},
#    8: {'weight': 6},
#    9: {'weight': 7},
#    11: {'weight': 1},
#    13: {'weight': 7},
#    14: {'weight': 1},
#    15: {'weight': 1},
#    16: {'weight': 4},
#    17: {'weight': 10},
#    18: {'weight': 3},
#    19: {'weight': 4},
#    21: {'weight': 5},
#    22: {'weight': 1},
#    23: {'weight': 7},
#    24: {'weight': 2},
#    25: {'weight': 3},
#    26: {'weight': 3},
#    27: {'weight': 1},
#    28: {'weight': 3},
#    29: {'weight': 5},
#    30: {'weight': 3},
#    31: {'weight': 6},
#    32: {'weight': 1},
#    33: {'weight': 7},
#    34: {'weight': 1}}),
#  (11,
#   {0: {'weight': 32},
#    1: {'weight': 12},
#    2: {'weight': 9},
#    3: {'weight': 15},
#    4: {'weight': 11},
#    5: {'weight': 6},
#    6: {'weight': 10},
#    8: {'weight': 8},
#    9: {'weight': 7},
#    10: {'weight': 1},
#    12: {'weight': 2},
#    13: {'weight': 4},
#    14: {'weight': 6},
#    15: {'weight': 5},
#    16: {'weight': 6},
#    17: {'weight': 7},
#    18: {'weight': 3},
#    19: {'weight': 7},
#    20: {'weight': 1},
#    21: {'weight': 5},
#    22: {'weight': 7},
#    23: {'weight': 9},
#    24: {'weight': 10},
#    25: {'weight': 3},
#    26: {'weight': 3},
#    27: {'weight': 5},
#    28: {'weight': 6},
#    29: {'weight': 3},
#    30: {'weight': 3},
#    31: {'weight': 2},
#    32: {'weight': 12},
#    33: {'weight': 2},
#    34: {'weight': 10}}),
#  (12,
#   {0: {'weight': 8},
#    1: {'weight': 7},
#    2: {'weight': 1},
#    3: {'weight': 2},
#    4: {'weight': 1},
#    5: {'weight': 5},
#    7: {'weight': 28},
#    8: {'weight': 1},
#    9: {'weight': 3},
#    11: {'weight': 2},
#    13: {'weight': 2},
#    14: {'weight': 2},
#    17: {'weight': 2},
#    18: {'weight': 4},
#    19: {'weight': 2},
#    20: {'weight': 35},
#    27: {'weight': 22},
#    28: {'weight': 1},
#    29: {'weight': 1},
#    30: {'weight': 1},
#    32: {'weight': 1},
#    34: {'weight': 2},
#    35: {'weight': 6}}),
#  (13,
#   {0: {'weight': 25},
#    1: {'weight': 15},
#    2: {'weight': 8},
#    3: {'weight': 2},
#    4: {'weight': 12},
#    5: {'weight': 8},
#    6: {'weight': 8},
#    7: {'weight': 1},
#    8: {'weight': 2},
#    9: {'weight': 7},
#    10: {'weight': 7},
#    11: {'weight': 4},
#    12: {'weight': 2},
#    14: {'weight': 5},
#    16: {'weight': 1},
#    17: {'weight': 4},
#    18: {'weight': 2},
#    19: {'weight': 2},
#    21: {'weight': 4},
#    22: {'weight': 1},
#    23: {'weight': 4},
#    24: {'weight': 3},
#    25: {'weight': 1},
#    26: {'weight': 1},
#    28: {'weight': 2},
#    29: {'weight': 3},
#    30: {'weight': 8},
#    31: {'weight': 4},
#    32: {'weight': 1},
#    33: {'weight': 1},
#    34: {'weight': 1},
#    35: {'weight': 1}}),
#  (14,
#   {0: {'weight': 57},
#    1: {'weight': 21},
#    4: {'weight': 4},
#    5: {'weight': 9},
#    6: {'weight': 6},
#    8: {'weight': 6},
#    10: {'weight': 1},
#    11: {'weight': 6},
#    12: {'weight': 2},
#    13: {'weight': 5},
#    15: {'weight': 38},
#    16: {'weight': 8},
#    17: {'weight': 8},
#    18: {'weight': 5},
#    19: {'weight': 8},
#    21: {'weight': 4},
#    22: {'weight': 63},
#    23: {'weight': 4},
#    24: {'weight': 6},
#    25: {'weight': 8},
#    26: {'weight': 8},
#    27: {'weight': 1},
#    28: {'weight': 1},
#    29: {'weight': 1},
#    30: {'weight': 1},
#    31: {'weight': 4},
#    32: {'weight': 3},
#    33: {'weight': 1},
#    34: {'weight': 1}}),
#  (15,
#   {0: {'weight': 57},
#    1: {'weight': 14},
#    4: {'weight': 2},
#    5: {'weight': 10},
#    6: {'weight': 7},
#    8: {'weight': 2},
#    10: {'weight': 1},
#    11: {'weight': 5},
#    14: {'weight': 38},
#    16: {'weight': 8},
#    17: {'weight': 6},
#    19: {'weight': 5},
#    21: {'weight': 2},
#    22: {'weight': 38},
#    23: {'weight': 4},
#    24: {'weight': 5},
#    25: {'weight': 5},
#    26: {'weight': 5},
#    28: {'weight': 3},
#    29: {'weight': 1},
#    31: {'weight': 3},
#    33: {'weight': 2}}),
#  (16,
#   {0: {'weight': 69},
#    1: {'weight': 28},
#    4: {'weight': 8},
#    5: {'weight': 7},
#    6: {'weight': 35},
#    7: {'weight': 1},
#    8: {'weight': 3},
#    10: {'weight': 4},
#    11: {'weight': 6},
#    13: {'weight': 1},
#    14: {'weight': 8},
#    15: {'weight': 8},
#    17: {'weight': 3},
#    19: {'weight': 12},
#    21: {'weight': 8},
#    22: {'weight': 7},
#    23: {'weight': 38},
#    24: {'weight': 4},
#    25: {'weight': 7},
#    26: {'weight': 7},
#    28: {'weight': 3},
#    29: {'weight': 2},
#    31: {'weight': 20},
#    32: {'weight': 1},
#    33: {'weight': 4},
#    34: {'weight': 2},
#    35: {'weight': 1}}),
#  (17,
#   {0: {'weight': 40},
#    1: {'weight': 13},
#    2: {'weight': 5},
#    4: {'weight': 8},
#    5: {'weight': 12},
#    6: {'weight': 6},
#    7: {'weight': 1},
#    8: {'weight': 2},
#    9: {'weight': 5},
#    10: {'weight': 10},
#    11: {'weight': 7},
#    12: {'weight': 2},
#    13: {'weight': 4},
#    14: {'weight': 8},
#    15: {'weight': 6},
#    16: {'weight': 3},
#    18: {'weight': 4},
#    19: {'weight': 2},
#    21: {'weight': 5},
#    22: {'weight': 8},
#    23: {'weight': 1},
#    24: {'weight': 5},
#    25: {'weight': 7},
#    26: {'weight': 7},
#    27: {'weight': 2},
#    28: {'weight': 8},
#    29: {'weight': 1},
#    30: {'weight': 5},
#    31: {'weight': 1},
#    33: {'weight': 3},
#    34: {'weight': 2},
#    35: {'weight': 2}}),
#  (18,
#   {0: {'weight': 26},
#    1: {'weight': 27},
#    2: {'weight': 21},
#    3: {'weight': 1},
#    4: {'weight': 6},
#    5: {'weight': 8},
#    6: {'weight': 10},
#    7: {'weight': 9},
#    8: {'weight': 11},
#    9: {'weight': 1},
#    10: {'weight': 3},
#    11: {'weight': 3},
#    12: {'weight': 4},
#    13: {'weight': 2},
#    14: {'weight': 5},
#    17: {'weight': 4},
#    19: {'weight': 3},
#    20: {'weight': 4},
#    21: {'weight': 8},
#    22: {'weight': 3},
#    23: {'weight': 2},
#    24: {'weight': 2},
#    25: {'weight': 2},
#    26: {'weight': 2},
#    27: {'weight': 2},
#    28: {'weight': 4},
#    30: {'weight': 1},
#    32: {'weight': 3},
#    34: {'weight': 1},
#    35: {'weight': 3}}),
#  (19,
#   {0: {'weight': 59},
#    1: {'weight': 19},
#    3: {'weight': 2},
#    4: {'weight': 6},
#    5: {'weight': 5},
#    6: {'weight': 10},
#    7: {'weight': 1},
#    8: {'weight': 3},
#    10: {'weight': 4},
#    11: {'weight': 7},
#    12: {'weight': 2},
#    13: {'weight': 2},
#    14: {'weight': 8},
#    15: {'weight': 5},
#    16: {'weight': 12},
#    17: {'weight': 2},
#    18: {'weight': 3},
#    20: {'weight': 1},
#    21: {'weight': 3},
#    22: {'weight': 8},
#    23: {'weight': 7},
#    24: {'weight': 7},
#    25: {'weight': 12},
#    26: {'weight': 12},
#    27: {'weight': 4},
#    28: {'weight': 2},
#    31: {'weight': 4},
#    32: {'weight': 2},
#    33: {'weight': 2},
#    34: {'weight': 6},
#    35: {'weight': 2}}),
#  (20,
#   {0: {'weight': 8},
#    1: {'weight': 6},
#    3: {'weight': 2},
#    5: {'weight': 1},
#    7: {'weight': 35},
#    8: {'weight': 3},
#    9: {'weight': 2},
#    11: {'weight': 1},
#    12: {'weight': 35},
#    18: {'weight': 4},
#    19: {'weight': 1},
#    24: {'weight': 1},
#    25: {'weight': 1},
#    26: {'weight': 1},
#    27: {'weight': 23},
#    32: {'weight': 2},
#    34: {'weight': 1},
#    35: {'weight': 10}}),
#  (21,
#   {0: {'weight': 38},
#    1: {'weight': 55},
#    2: {'weight': 3},
#    3: {'weight': 4},
#    4: {'weight': 6},
#    5: {'weight': 7},
#    6: {'weight': 8},
#    7: {'weight': 1},
#    8: {'weight': 12},
#    9: {'weight': 1},
#    10: {'weight': 5},
#    11: {'weight': 5},
#    13: {'weight': 4},
#    14: {'weight': 4},
#    15: {'weight': 2},
#    16: {'weight': 8},
#    17: {'weight': 5},
#    18: {'weight': 8},
#    19: {'weight': 3},
#    22: {'weight': 4},
#    23: {'weight': 9},
#    24: {'weight': 2},
#    25: {'weight': 2},
#    26: {'weight': 2},
#    28: {'weight': 2},
#    29: {'weight': 1},
#    30: {'weight': 1},
#    31: {'weight': 5},
#    32: {'weight': 2},
#    33: {'weight': 1},
#    34: {'weight': 1}}),
#  (22,
#   {0: {'weight': 54},
#    1: {'weight': 19},
#    4: {'weight': 2},
#    5: {'weight': 8},
#    6: {'weight': 5},
#    8: {'weight': 3},
#    10: {'weight': 1},
#    11: {'weight': 7},
#    13: {'weight': 1},
#    14: {'weight': 63},
#    15: {'weight': 38},
#    16: {'weight': 7},
#    17: {'weight': 8},
#    18: {'weight': 3},
#    19: {'weight': 8},
#    21: {'weight': 4},
#    23: {'weight': 4},
#    24: {'weight': 6},
#    25: {'weight': 8},
#    26: {'weight': 8},
#    27: {'weight': 1},
#    28: {'weight': 2},
#    29: {'weight': 1},
#    30: {'weight': 1},
#    31: {'weight': 4},
#    32: {'weight': 2},
#    33: {'weight': 1},
#    34: {'weight': 1}}),
#  (23,
#   {0: {'weight': 55},
#    1: {'weight': 18},
#    2: {'weight': 2},
#    4: {'weight': 12},
#    5: {'weight': 3},
#    6: {'weight': 6},
#    7: {'weight': 1},
#    8: {'weight': 4},
#    9: {'weight': 2},
#    10: {'weight': 7},
#    11: {'weight': 9},
#    13: {'weight': 4},
#    14: {'weight': 4},
#    15: {'weight': 4},
#    16: {'weight': 38},
#    17: {'weight': 1},
#    18: {'weight': 2},
#    19: {'weight': 7},
#    21: {'weight': 9},
#    22: {'weight': 4},
#    24: {'weight': 2},
#    25: {'weight': 8},
#    26: {'weight': 8},
#    27: {'weight': 2},
#    28: {'weight': 3},
#    29: {'weight': 4},
#    30: {'weight': 1},
#    31: {'weight': 25},
#    32: {'weight': 4},
#    33: {'weight': 2},
#    34: {'weight': 6},
#    35: {'weight': 2}}),
#  (24,
#   {0: {'weight': 31},
#    1: {'weight': 11},
#    2: {'weight': 7},
#    3: {'weight': 5},
#    4: {'weight': 4},
#    5: {'weight': 6},
#    6: {'weight': 9},
#    8: {'weight': 4},
#    9: {'weight': 2},
#    10: {'weight': 2},
#    11: {'weight': 10},
#    13: {'weight': 3},
#    14: {'weight': 6},
#    15: {'weight': 5},
#    16: {'weight': 4},
#    17: {'weight': 5},
#    18: {'weight': 2},
#    19: {'weight': 7},
#    20: {'weight': 1},
#    21: {'weight': 2},
#    22: {'weight': 6},
#    23: {'weight': 2},
#    25: {'weight': 9},
#    26: {'weight': 9},
#    28: {'weight': 2},
#    29: {'weight': 1},
#    30: {'weight': 1},
#    31: {'weight': 3},
#    32: {'weight': 3},
#    33: {'weight': 1},
#    34: {'weight': 1},
#    35: {'weight': 1}}),
#  (25,
#   {0: {'weight': 63},
#    1: {'weight': 16},
#    2: {'weight': 1},
#    4: {'weight': 4},
#    5: {'weight': 6},
#    6: {'weight': 5},
#    8: {'weight': 2},
#    9: {'weight': 1},
#    10: {'weight': 3},
#    11: {'weight': 3},
#    13: {'weight': 1},
#    14: {'weight': 8},
#    15: {'weight': 5},
#    16: {'weight': 7},
#    17: {'weight': 7},
#    18: {'weight': 2},
#    19: {'weight': 12},
#    20: {'weight': 1},
#    21: {'weight': 2},
#    22: {'weight': 8},
#    23: {'weight': 8},
#    24: {'weight': 9},
#    26: {'weight': 65},
#    27: {'weight': 1},
#    28: {'weight': 2},
#    29: {'weight': 2},
#    31: {'weight': 4},
#    32: {'weight': 1},
#    33: {'weight': 3},
#    34: {'weight': 6},
#    35: {'weight': 1}}),
#  (26,
#   {0: {'weight': 63},
#    1: {'weight': 16},
#    2: {'weight': 1},
#    4: {'weight': 4},
#    5: {'weight': 6},
#    6: {'weight': 5},
#    8: {'weight': 2},
#    9: {'weight': 1},
#    10: {'weight': 3},
#    11: {'weight': 3},
#    13: {'weight': 1},
#    14: {'weight': 8},
#    15: {'weight': 5},
#    16: {'weight': 7},
#    17: {'weight': 7},
#    18: {'weight': 2},
#    19: {'weight': 12},
#    20: {'weight': 1},
#    21: {'weight': 2},
#    22: {'weight': 8},
#    23: {'weight': 8},
#    24: {'weight': 9},
#    25: {'weight': 65},
#    27: {'weight': 1},
#    28: {'weight': 2},
#    29: {'weight': 2},
#    31: {'weight': 4},
#    32: {'weight': 1},
#    33: {'weight': 3},
#    34: {'weight': 6},
#    35: {'weight': 1}}),
#  (27,
#   {0: {'weight': 5},
#    1: {'weight': 5},
#    3: {'weight': 1},
#    4: {'weight': 1},
#    5: {'weight': 5},
#    6: {'weight': 1},
#    7: {'weight': 28},
#    8: {'weight': 2},
#    9: {'weight': 2},
#    10: {'weight': 1},
#    11: {'weight': 5},
#    12: {'weight': 22},
#    14: {'weight': 1},
#    17: {'weight': 2},
#    18: {'weight': 2},
#    19: {'weight': 4},
#    20: {'weight': 23},
#    22: {'weight': 1},
#    23: {'weight': 2},
#    25: {'weight': 1},
#    26: {'weight': 1},
#    28: {'weight': 1},
#    30: {'weight': 2},
#    32: {'weight': 2},
#    34: {'weight': 11},
#    35: {'weight': 10}}),
#  (28,
#   {0: {'weight': 26},
#    1: {'weight': 14},
#    2: {'weight': 4},
#    3: {'weight': 2},
#    4: {'weight': 4},
#    5: {'weight': 1},
#    6: {'weight': 6},
#    8: {'weight': 6},
#    9: {'weight': 1},
#    10: {'weight': 3},
#    11: {'weight': 6},
#    12: {'weight': 1},
#    13: {'weight': 2},
#    14: {'weight': 1},
#    15: {'weight': 3},
#    16: {'weight': 3},
#    17: {'weight': 8},
#    18: {'weight': 4},
#    19: {'weight': 2},
#    21: {'weight': 2},
#    22: {'weight': 2},
#    23: {'weight': 3},
#    24: {'weight': 2},
#    25: {'weight': 2},
#    26: {'weight': 2},
#    27: {'weight': 1},
#    29: {'weight': 2},
#    30: {'weight': 2},
#    31: {'weight': 1},
#    32: {'weight': 3},
#    33: {'weight': 5}}),
#  (29,
#   {0: {'weight': 10},
#    1: {'weight': 4},
#    2: {'weight': 10},
#    3: {'weight': 1},
#    4: {'weight': 8},
#    5: {'weight': 1},
#    6: {'weight': 5},
#    9: {'weight': 4},
#    10: {'weight': 5},
#    11: {'weight': 3},
#    12: {'weight': 1},
#    13: {'weight': 3},
#    14: {'weight': 1},
#    15: {'weight': 1},
#    16: {'weight': 2},
#    17: {'weight': 1},
#    21: {'weight': 1},
#    22: {'weight': 1},
#    23: {'weight': 4},
#    24: {'weight': 1},
#    25: {'weight': 2},
#    26: {'weight': 2},
#    28: {'weight': 2},
#    30: {'weight': 5},
#    31: {'weight': 3},
#    32: {'weight': 1},
#    33: {'weight': 2},
#    35: {'weight': 2}}),
#  (30,
#   {0: {'weight': 15},
#    1: {'weight': 4},
#    2: {'weight': 1},
#    3: {'weight': 2},
#    4: {'weight': 3},
#    5: {'weight': 4},
#    6: {'weight': 1},
#    7: {'weight': 1},
#    8: {'weight': 1},
#    9: {'weight': 6},
#    10: {'weight': 3},
#    11: {'weight': 3},
#    12: {'weight': 1},
#    13: {'weight': 8},
#    14: {'weight': 1},
#    17: {'weight': 5},
#    18: {'weight': 1},
#    21: {'weight': 1},
#    22: {'weight': 1},
#    23: {'weight': 1},
#    24: {'weight': 1},
#    27: {'weight': 2},
#    28: {'weight': 2},
#    29: {'weight': 5},
#    31: {'weight': 1},
#    32: {'weight': 1},
#    33: {'weight': 2},
#    34: {'weight': 5},
#    35: {'weight': 1}}),
#  (31,
#   {0: {'weight': 37},
#    1: {'weight': 12},
#    2: {'weight': 1},
#    3: {'weight': 1},
#    4: {'weight': 10},
#    5: {'weight': 3},
#    6: {'weight': 6},
#    8: {'weight': 2},
#    10: {'weight': 6},
#    11: {'weight': 2},
#    13: {'weight': 4},
#    14: {'weight': 4},
#    15: {'weight': 3},
#    16: {'weight': 20},
#    17: {'weight': 1},
#    19: {'weight': 4},
#    21: {'weight': 5},
#    22: {'weight': 4},
#    23: {'weight': 25},
#    24: {'weight': 3},
#    25: {'weight': 4},
#    26: {'weight': 4},
#    28: {'weight': 1},
#    29: {'weight': 3},
#    30: {'weight': 1},
#    32: {'weight': 1},
#    33: {'weight': 1},
#    34: {'weight': 2}}),
#  (32,
#   {0: {'weight': 13},
#    1: {'weight': 18},
#    2: {'weight': 3},
#    3: {'weight': 1},
#    4: {'weight': 2},
#    5: {'weight': 2},
#    6: {'weight': 4},
#    8: {'weight': 9},
#    10: {'weight': 1},
#    11: {'weight': 12},
#    12: {'weight': 1},
#    13: {'weight': 1},
#    14: {'weight': 3},
#    16: {'weight': 1},
#    18: {'weight': 3},
#    19: {'weight': 2},
#    20: {'weight': 2},
#    21: {'weight': 2},
#    22: {'weight': 2},
#    23: {'weight': 4},
#    24: {'weight': 3},
#    25: {'weight': 1},
#    26: {'weight': 1},
#    27: {'weight': 2},
#    28: {'weight': 3},
#    29: {'weight': 1},
#    30: {'weight': 1},
#    31: {'weight': 1},
#    33: {'weight': 2},
#    34: {'weight': 4}}),
#  (33,
#   {0: {'weight': 29},
#    1: {'weight': 7},
#    4: {'weight': 6},
#    5: {'weight': 3},
#    6: {'weight': 2},
#    8: {'weight': 2},
#    10: {'weight': 7},
#    11: {'weight': 2},
#    13: {'weight': 1},
#    14: {'weight': 1},
#    15: {'weight': 2},
#    16: {'weight': 4},
#    17: {'weight': 3},
#    19: {'weight': 2},
#    21: {'weight': 1},
#    22: {'weight': 1},
#    23: {'weight': 2},
#    24: {'weight': 1},
#    25: {'weight': 3},
#    26: {'weight': 3},
#    28: {'weight': 5},
#    29: {'weight': 2},
#    30: {'weight': 2},
#    31: {'weight': 1},
#    32: {'weight': 2}}),
#  (34,
#   {0: {'weight': 25},
#    1: {'weight': 8},
#    2: {'weight': 2},
#    3: {'weight': 2},
#    4: {'weight': 2},
#    6: {'weight': 4},
#    8: {'weight': 2},
#    9: {'weight': 1},
#    10: {'weight': 1},
#    11: {'weight': 10},
#    12: {'weight': 2},
#    13: {'weight': 1},
#    14: {'weight': 1},
#    16: {'weight': 2},
#    17: {'weight': 2},
#    18: {'weight': 1},
#    19: {'weight': 6},
#    20: {'weight': 1},
#    21: {'weight': 1},
#    22: {'weight': 1},
#    23: {'weight': 6},
#    24: {'weight': 1},
#    25: {'weight': 6},
#    26: {'weight': 6},
#    27: {'weight': 11},
#    30: {'weight': 5},
#    31: {'weight': 2},
#    32: {'weight': 4}}),
#  (35,
#   {0: {'weight': 5},
#    1: {'weight': 4},
#    5: {'weight': 1},
#    7: {'weight': 25},
#    9: {'weight': 2},
#    12: {'weight': 6},
#    13: {'weight': 1},
#    16: {'weight': 1},
#    17: {'weight': 2},
#    18: {'weight': 3},
#    19: {'weight': 2},
#    20: {'weight': 10},
#    23: {'weight': 2},
#    24: {'weight': 1},
#    25: {'weight': 1},
#    26: {'weight': 1},
#    27: {'weight': 10},
#    29: {'weight': 2},
#    30: {'weight': 1}})]

# %% [markdown]
# ## (9) 시각화
# 생성된 네트워크에 대해서 데이터를 시각화하여 나타낸다. 여기서 labels 값으로 이전에 생성한 id2word를 이용한다.

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
#
import seaborn as sns

sns.set(rc = {'figure.figsize':(10,6)})
plt.rc('font', family=font_name)

def get_node_size(node_values):
    nsize=np.array([v for v in node_values])
    nsize = 1000*(nsize-min(nsize))/(max(nsize)-min(nsize))
    
    return nsize


dc = nx.degree_centrality(network).values()

# 시각화 위한
plt.figure(figsize = (20,30))
plt.axis('off') # 꺼주기

options = {
    'edge_color':'gray',
    'font_color':"black"
}

plt.subplot(322)
plt.title('Degree Centrality', fontsize=16)
nx.draw_networkx(network, font_size=16, 
                 node_color = list(dc), node_size = get_node_size(dc), 
                 labels=id2word, font_family=font_name, **options,
                 alpha=0.7, cmap=plt.cm.Blues)

plt.show()
